# %% [markdown]
# # Congress and Bills Dataset
# We associate members of the House of Representatives (HoR) with the respective bills they authored.

# %% [markdown]
# ## Importing Datasets
# The bills dataset in the `18th-congress-bills` folder and the HoR members data in the `congress-members-rip` folder are imported.

# %%
import pandas as pd

bills_df = pd.read_csv('18th-congress-bills/hor_bills.csv', encoding='utf-8')
reps_df = pd.read_csv('congress-members-rip/18th_congress_hor.csv', encoding='utf-8')

# %%
reps_df
# Out:
#                               rep_name         rep_region rep_subdistrict  \
# 0            Abante, Bienvenido Jr. M.             Manila    6th District
# 1      Abaya, Francis Gerald Aguinaldo             Cavite    1st District
# 2               Abellanosa, Rodrigo A.          Cebu City    2nd District
# 3                Abu, Raneo "Ranie" E.           Batangas    2nd District
# 4    Abueg-Zaldivar, Cyrille "Beng" F.            Palawan    2nd District
# ..                                 ...                ...             ...
# 303                Yu, Divina Grace C.  Zamboanga del Sur    1st District
# 304      Zamora, Manuel "Way Kurat" E.       Davao de Oro    1st District
# 305                 Zamora, Ronaldo B.      San Juan City   Lone District
# 306          Zarate, Carlos Isagani T.                NaN             NaN
# 307                  Zubiri, Manuel F.           Bukidnon    3rd District
#
#       partylist            link                             name   party  \
# 0           NaN        abante-b   ABANTE, BIENVENIDO JR. MIRANDO  ASENSO
# 1           NaN        abaya-fg  ABAYA, FRANCIS GERALD AGUINALDO      LP
# 2           NaN    abellanosa-r     ABELLANOSA, RODRIGO ABELLANA     LDP
# 3           NaN           abu-r              ABU, RANEO ENRIQUEZ      NP
# 4           NaN  abueg-zaldivar           ABUEG, CYRILLE FABELLO     PPP
# ..          ...             ...                              ...     ...
# 303         NaN            yu-d         YU, DIVINA GRACE CABARDO  PDPLBN
# 304         NaN        zamora-m          ZAMORA, MANUEL ESQUIVEL     HNP
# 305         NaN        zamora-r            ZAMORA, RONALDO BAYAN  PDPLBN
# 306  BAYAN MUNA        zarate-c                              NaN     NaN
# 307         NaN        zubiri-m         ZUBIRI, MANUEL FERNANDEZ     BPP
#
#        votes    conf_date       district                   region  \
# 0     49,795  14-May-2019   6th District  NATIONAL CAPITAL REGION
# 1    117,031  16-May-2019   1st District              REGION IV-A
# 2    163,752  15-May-2019   2nd District               REGION VII
# 3    117,205  16-May-2019   2nd District              REGION IV-A
# 4    112,960  17-May-2019   2nd District              REGION IV-B
# ..       ...          ...            ...                      ...
# 303  164,990  18-May-2019   1st District                REGION IX
# 304   78,257  17-May-2019   1st District                REGION XI
# 305   35,386  13-May-2019  Lone District  NATIONAL CAPITAL REGION
# 306      NaN          NaN            NaN                      NaN
# 307  136,768  18-May-2019   3rd District                 REGION X
#
#            subdistrict
# 0               Manila
# 1               Cavite
# 2            Cebu City
# 3             Batangas
# 4              Palawan
# ..                 ...
# 303  Zamboanga del Sur
# 304       Davao de Oro
# 305      San Juan City
# 306                NaN
# 307           Bukidnon
#
# [308 rows x 12 columns]

# %%
bills_df.iloc[9399]
# Out:
# ID                                                                            HB09411
# Significance                                                                 National
# Date Filed                                                                 2021-05-24
# Full Title                          AN ACT\nPROVIDING FOR ADDITIONAL MECHANISMS TO...
# Principal Author/s                  FUENTEBELLA, ARNIE B.;SAKALURAN, PRINCESS RIHA...
# Date Read                                                                  2021-05-24
# Primary Referral                                                     ECONOMIC AFFAIRS
# Bill Status                         Approved by the House on 2021-06-01, transmitt...
# Mother Bill Status                                                                NaN
# Date Approved on Second Reading                                            2021-05-25
# Date Approved on Third Reading                                             2021-06-01
# Senate Bill Counterpart                                                           NaN
# Date Acted Upon By the President                                                  NaN
# Republic Act No.                                                                  NaN
# Author Count                                                                      288
# Name: 9399, dtype: object

# %% [markdown]
# Entries which are not house bills are removed.

# %%
bills_df = bills_df[bills_df['ID'].str[:2]=='HB']
bills_df
# Out:
#             ID Significance  Date Filed  \
# 0      HB00001     National  2019-07-01
# 1      HB00002     National  2019-07-01
# 2      HB00003     National  2019-07-01
# 3      HB00004     National  2019-07-01
# 4      HB00005     National  2019-07-01
# ...        ...          ...         ...
# 10817  HB10829          NaN  2022-03-23
# 10818  HB10830          NaN  2022-03-23
# 10819  HB10831          NaN  2022-03-29
# 10820  HB10832          NaN  2022-03-31
# 10821  HB10833          NaN  2022-04-11
#
#                                               Full Title  \
# 0      AN ACT INSTITUTIONALIZING A NATIONAL VALUES, E...
# 1      AN ACT CREATING THE DEPARTMENT OF OVERSEAS FIL...
# 2      AN ACT PROVIDING FOR A NATIONAL PROGRAM TO SUP...
# 3      AN ACT CREATING THE EMERGENCY RESPONSE DEPARTM...
# 4      AN ACT INSTITUTIONALIZING MICROFINANCE PROGRAM...
# ...                                                  ...
# 10817  AN ACT CREATING THE "COUNCIL FOR THE BUILT ENV...
# 10818  AN ACT STRENGTHENING THE ARCHITECTURE PROFESSI...
# 10819  AN ACT POSTPONING THE DECEMBER 2022 BARANGAY A...
# 10820  AN ACT MANDATING ALL EXECUTIVE DEPARTMENTS, BU...
# 10821  AN ACT RENAMING THE NINOY AQUINO INTERNATIONAL...
#
#                                       Principal Author/s   Date Read  \
# 0      UNGAB, ISIDRO T.;CAYETANO, ALAN PETER "COMPAÑE...  2019-07-23
# 1      DUTERTE, PAOLO Z.;CAYETANO, MARIA LAARNI;CAYET...  2019-07-23
# 2                    CAYETANO, ALAN PETER "COMPAÑERO" S.  2019-07-23
# 3      DUTERTE, PAOLO Z.;CAYETANO, ALAN PETER "COMPAÑ...  2019-07-23
# 4                    CAYETANO, ALAN PETER "COMPAÑERO" S.  2019-07-23
# ...                                                  ...         ...
# 10817                                RODRIGUEZ, RUFUS B.         NaN
# 10818                                RODRIGUEZ, RUFUS B.         NaN
# 10819                                  CARDEMA, DUCIELLE         NaN
# 10820  FERNANDEZ, DAN S.;CAYETANO, ALAN PETER "COMPAÑ...         NaN
# 10821                                  CARDEMA, DUCIELLE         NaN
#
#                                      Primary Referral  \
# 0                         BASIC EDUCATION AND CULTURE
# 1                           GOVERNMENT REORGANIZATION
# 2                                 WELFARE OF CHILDREN
# 3                           GOVERNMENT REORGANIZATION
# 4      MICRO, SMALL AND MEDIUM ENTERPRISE DEVELOPMENT
# ...                                               ...
# 10817                                             NaN
# 10818                                             NaN
# 10819                                             NaN
# 10820                                             NaN
# 10821                                             NaN
#
#                                              Bill Status  \
# 0                                 Substituted by HB05829
# 1                                 Substituted by HB05832
# 2      Transmitted to the Committee on Appropriations...
# 3                                 Substituted by HB05989
# 4      Pending with the Committee on MICRO, SMALL AND...
# ...                                                  ...
# 10817      Pending First Reading (Filed last 2022-03-23)
# 10818      Pending First Reading (Filed last 2022-03-23)
# 10819      Pending First Reading (Filed last 2022-03-29)
# 10820      Pending First Reading (Filed last 2022-03-31)
# 10821      Pending First Reading (Filed last 2022-04-11)
#
#                                       Mother Bill Status  \
# 0             Republic Act RA11476 enacted on 2020-06-25
# 1             Republic Act RA11641 enacted on 2021-12-30
# 2                                                    NaN
# 3      Approved by the House on 2020-09-22, transmitt...
# 4                                                    NaN
# ...                                                  ...
# 10817                                                NaN
# 10818                                                NaN
# 10819                                                NaN
# 10820                                                NaN
# 10821                                                NaN
#
#       Date Approved on Second Reading Date Approved on Third Reading  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 10817                             NaN                            NaN
# 10818                             NaN                            NaN
# 10819                             NaN                            NaN
# 10820                             NaN                            NaN
# 10821                             NaN                            NaN
#
#       Senate Bill Counterpart Date Acted Upon By the President  \
# 0                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 3                         NaN                              NaN
# 4                         NaN                              NaN
# ...                       ...                              ...
# 10817                     NaN                              NaN
# 10818                     NaN                              NaN
# 10819                     NaN                              NaN
# 10820                     NaN                              NaN
# 10821                     NaN                              NaN
#
#       Republic Act No.  Author Count
# 0                  NaN             3
# 1                  NaN             3
# 2                  NaN             1
# 3                  NaN             2
# 4                  NaN             1
# ...                ...           ...
# 10817              NaN             1
# 10818              NaN             1
# 10819              NaN             1
# 10820              NaN             5
# 10821              NaN             1
#
# [10822 rows x 15 columns]

# %% [markdown]
# Make sure each bill has an associated author field.

# %%
bills_df[bills_df['Principal Author/s'].isna()]
# Out:
#            ID Significance  Date Filed  \
# 1596  HB01603     National  2019-07-08
# 9988  HB1-485          NaN  2021-11-12
#
#                                              Full Title Principal Author/s  \
# 1596  AN ACT GRANTING DULY APPOINTED REGIONAL TRIAL ...                NaN
# 9988  AN ACT INSTITUTIONALIZING A SYSTEM OF FREE FOR...                NaN
#
#        Date Read Primary Referral  \
# 1596  2019-07-24          JUSTICE
# 9988         NaN              NaN
#
#                                             Bill Status Mother Bill Status  \
# 1596  Pending with the Committee on JUSTICE since 20...                NaN
# 9988      Pending First Reading (Filed last 2021-11-12)                NaN
#
#      Date Approved on Second Reading Date Approved on Third Reading  \
# 1596                             NaN                            NaN
# 9988                             NaN                            NaN
#
#      Senate Bill Counterpart Date Acted Upon By the President  \
# 1596                     NaN                              NaN
# 9988                     NaN                              NaN
#
#      Republic Act No.  Author Count
# 1596              NaN             0
# 9988              NaN             0

# %% [markdown]
# Fill in author field of HB01603. Row 9988 is dropped since it is a duplicate of HB10485.

# %%
bills_df.loc[bills_df['ID']=='HB01603', 'Principal Author/s'] = 'Castelo, Precious Hipolito' # from https://hrep-website.s3.ap-southeast-1.amazonaws.com/legisdocs/basic_18/HB01603.pdf
bills_df.loc[bills_df['ID']=='HB01603', 'Author Count'] = 1
bills_df = bills_df.drop(9988, axis=0)

bills_df[bills_df['Principal Author/s'].isna()]
# Out:
# Empty DataFrame
# Columns: [ID, Significance, Date Filed, Full Title, Principal Author/s, Date Read, Primary Referral, Bill Status, Mother Bill Status, Date Approved on Second Reading, Date Approved on Third Reading, Senate Bill Counterpart, Date Acted Upon By the President, Republic Act No., Author Count]
# Index: []

# %% [markdown]
# There are 308 members of the HoR.

# %%
rep_names = reps_df['rep_name'].str.lower()
rep_names = rep_names.to_dict()
len(reps_df)
# Out:
# 308

# %% [markdown]
# Mapping from the representative's name to an integer denoting their index and back are created.

# %%
num_to_rep = rep_names
rep_names = dict(zip(rep_names.values(), rep_names.keys()))
rep_names, len(rep_names)
rep_names
# Out:
# {'abante, bienvenido jr. m.': 0,
#  'abaya, francis gerald aguinaldo': 1,
#  'abellanosa, rodrigo a.': 2,
#  'abu, raneo "ranie" e.': 3,
#  'abueg-zaldivar, cyrille "beng" f.': 4,
#  'abunda, maria fe r.': 5,
#  'acop, resurreccion m.': 6,
#  'acosta, gil "kabarangay jr." a.': 7,
#  'acosta-alba, maria lourdes': 8,
#  'adiong, ansaruddin abdul malik a.': 9,
#  'advincula, alex "aa" l.': 10,
#  'agabas, tyrone d.': 11,
#  'agarao, benjamin jr. c.': 12,
#  'aglipay, michael edgar y.': 13,
#  'aguinaldo, naealla bainto': 14,
#  'albano, antonio "tonypet" t.': 15,
#  'albano, rodolfo b.': 16,
#  'alfonso, samantha louise vargas': 17,
#  'almario, joel mayo z.': 18,
#  'alonte, marlyn "len" b.': 19,
#  'alvarez, franz "chicoy" e.': 20,
#  'alvarez, genaro jr. m.': 21,
#  'alvarez, pantaleon d.': 22,
#  'amante-matba, ma. angelica m.': 23,
#  'amatong, isagani s.': 24,
#  'andaya, marissa': 25,
#  'angara, rommel rico t.': 26,
#  'aragones, sol': 27,
#  'arbison, munir m.': 28,
#  'arenas, rose marie "baby" j.': 29,
#  'arroyo, ma. lourdes t.': 30,
#  'atienza, jose jr. l.': 31,
#  'aumentado, erico aristotle c.': 32,
#  'bañas-nograles, shirlyn l.': 33,
#  'babasa, leonardo jr. l.': 34,
#  'bagatsing, cristal l.': 35,
#  'balindong, yasser alonto': 36,
#  'barba, angelo marcos': 37,
#  'barbers, robert ace s.': 38,
#  'baronda, julienne "jam" l.': 39,
#  'barzaga, elpidio jr. f.': 40,
#  'bascug, alfel m.': 41,
#  'bautista, claudine diana d.': 42,
#  'bautista-bandigan, lorna p.': 43,
#  'belmonte, jose christopher y.': 44,
#  'benitez, francisco "kiko"  b.': 45,
#  'bernos, joseph sto. niño b.': 46,
#  'biazon, ruffy b.': 47,
#  'billones, emmanuel "tawi"': 48,
#  'biron, braeden john q.': 49,
#  'bolilia, lianda b.': 50,
#  'bondoc, juan pablo "rimpy" p.': 51,
#  'bordado, gabriel jr. h.': 52,
#  'bravo, narciso jr. r.': 53,
#  'brosas, arlene d.': 54,
#  'bulut, elias jr. c.': 55,
#  'bustos, jorge "patrol"': 56,
#  'cabatbat, argel joseph t.': 57,
#  'cabochan, manuel iii dg.': 58,
#  'cabredo, fernando t.': 59,
#  'cagas, mercedes "didi" c.': 60,
#  'calderon, peter john d.': 61,
#  'calixto, antonino g.': 62,
#  'caminero, wilfredo "willy" s.': 63,
#  'campos, luis jr. n.': 64,
#  'canama, sabiniano s.': 65,
#  'caoagdan, rudy s., dpa': 66,
#  'cardema, ducielle marie s.': 67,
#  'cari, carl nicolas c.': 68,
#  'castelo, precious hipolito': 69,
#  'castro, france l.': 70,
#  'castro, fredenil "fred" h.': 71,
#  'cayetano, alan peter "compañero" s.': 72,
#  'cayetano, maria laarni': 73,
#  'celeste, arnold  "noli" d.': 74,
#  'chatto, edgar m.': 75,
#  'chipeco, joaquin jr. m.': 76,
#  'chungalao, solomon r.': 77,
#  'co, angelica natasha': 78,
#  'co, elizaldy s.': 79,
#  'cojuangco, carlos o.': 80,
#  'collantes, ma. theresa v.': 81,
#  'crisologo, anthony peter "onyx"  d.': 82,
#  'cua, junie e.': 83,
#  'cuaresma, luisa lloren': 84,
#  'cueva, leo rafael m.': 85,
#  'cullamat, eufemia "ka femia" c.': 86,
#  'dagooc, sergio c.': 87,
#  'dalipe, manuel jose "mannix" m.': 88,
#  'dalog, maximo jr. y.': 89,
#  'datol, francisco jr. g.': 90,
#  'daza, paul ruiz': 91,
#  'de jesus, presley c.': 92,
#  'de venecia, christopher v.p.': 93,
#  'defensor, lorenz r.': 94,
#  'defensor, michael t.': 95,
#  'del mar, raul v.': 96,
#  'delos santos, alfred c.': 97,
#  'delos santos, edward c.': 98,
#  'deloso-montalla, cheryl p.': 99,
#  'dimaporo, abdullah d.': 100,
#  'dimaporo, mohamad khalid q.': 101,
#  'duavit, michael john r.': 102,
#  'dujali, alan "aldu" r.': 103,
#  'duterte, paolo z.': 104,
#  'dy, faustino michael carlos iii t.': 105,
#  'dy, faustino v "inno" a.': 106,
#  'dy, ian paul l.': 107,
#  'ebcas, adriano a.': 108,
#  'ecleo, alan 1 b.': 109,
#  'elago, sarah jane i.': 110,
#  'enverga, wilfrido mark m.': 111,
#  'erice, edgar r.': 112,
#  'eriguel, sandra y., m.d.': 113,
#  'ermita-buhain, elenita milagros "eileen"': 114,
#  'escudero, evelina g.': 115,
#  'espina, gerardo  jr. "gerryboy"  j.': 116,
#  'espino, jumel anthony i.': 117,
#  'estrella, conrado iii m.': 118,
#  'fariñas, ria christina g.': 119,
#  'fariñas, rudys caesar i g.': 120,
#  'fernandez, dan s.': 121,
#  'fernando, bayani f.': 122,
#  'ferrer, juliet marie de leon': 123,
#  'ferrer, luis iv "jon-jon" a.': 124,
#  'flores, jonathan keith t.': 125,
#  'fongwan, nestor b.': 126,
#  'fortun, lawrence "law" h.': 127,
#  'fortuno, jocelyn f.': 128,
#  "frasco, vincent franco 'duke'  d.": 129,
#  'fuentebella, arnie b.': 130,
#  'gaite, ferdinand r.': 131,
#  'garbin, alfredo jr. a.': 132,
#  'garcia, jose enrique iii "joet" s.': 133,
#  'garcia, pablo john f.': 134,
#  'garcia, vincent j.': 135,
#  'garin, janette l.': 136,
#  'garin, sharon s.': 137,
#  'gasataya, greg g.': 138,
#  'gatchalian, wes': 139,
#  'gato, ciriaco jr. b.': 140,
#  'geron, rico b.': 141,
#  'go, ed christopher  s.': 142,
#  'go, mark o.': 143,
#  'gonzaga, ruwel peter s.': 144,
#  'gonzales, aurelio jr. "dong" d.': 145,
#  'gonzales, neptali ii m.': 146,
#  'gonzalez, sandro l.': 147,
#  'gorriceta, michael b.': 148,
#  'guico, ramon iii "mon-mon" v.': 149,
#  'gullas, eduardo "eddie" r.': 150,
#  'guya, godofredo n.': 151,
#  'haresco, teodorico jr. t.': 152,
#  'hataman,  mujiv s.': 153,
#  'hernandez, ferdinand l.': 154,
#  'herrera-dy, bernadette "bh"': 155,
#  'hofer, ann k.': 156,
#  'jalosjos, romeo jr. m.': 157,
#  'javier, lolita t.': 158,
#  'jimenez, cesar jr. "jawo" l.': 159,
#  'kho, elisa "olga" t.': 160,
#  'kho, wilton "tonton" tan': 161,
#  'khonghun, jeffrey d.': 162,
#  'labadlabad, glona g.': 163,
#  'lacson, virgilio s.': 164,
#  'lacson-noel, josephine veronique r.': 165,
#  'lagman, edcel c.': 166,
#  'lagon, sonny "sl" l.': 167,
#  'lara, joseph "jojo" l.': 168,
#  'lazatin, carmelo ii "jon"  b.': 169,
#  'leachon, doy c.': 170,
#  'legarda, loren': 171,
#  'lim, aloy': 172,
#  'limkaichong, jocelyn sy': 173,
#  'lopez, jose antonio g.': 174,
#  'lopez, manuel luis t.': 175,
#  'loyola, dahlia a.': 176,
#  'lusotan, macnell m.': 177,
#  'macapagal arroyo, juan miguel': 178,
#  'maceda, edward vera perez': 179,
#  'madrona, eleandro jesus f.': 180,
#  'malapitan, dale "along" r.': 181,
#  'mangaoang, allen jesse c.': 182,
#  'mangudadatu, esmael g.': 183,
#  'marcoleta, rodante d.': 184,
#  'mariano-hernandez, ruth': 185,
#  'mariño,  mario vittorio "marvey" a.': 186,
#  'marquez, carlito s.': 187,
#  'martinez, eric m.': 188,
#  'matba, rashidin h.': 189,
#  'matugas, francisco jose ii "bingo" f., cpa,ceso,llb': 190,
#  'mendoza, raymond democrito c.': 191,
#  'mercado, roger g.': 192,
#  'momo, romeo sr. s.': 193,
#  'natividad-nagaño, maricel g., md.': 194,
#  'nava, ma. lucille l., m.d.': 195,
#  'nieto, john marvin "yul servo" c.': 196,
#  'noel, florencio g.': 197,
#  'nograles, jericho jonas b.': 198,
#  'nograles, juan fidel felipe f.': 199,
#  'nolasco, ramon jr. c.': 200,
#  'nuñez-malanyaon, corazon t.': 201,
#  'oaminal, henry s.': 202,
#  'olivarez, eric l.': 203,
#  'ong, jose jr. "jun" l.': 204,
#  'ong, ronnie l.': 205,
#  'ordanes, rodolfo m.': 206,
#  'ortega, pablo c.': 207,
#  'ouano-dizon, emmarie "lolypop" m.': 208,
#  'pacquiao, alberto "bobby" d.': 209,
#  'pacquiao, rogelio "ruel" d.': 210,
#  'padiernos, jose gay g.': 211,
#  'paduano, joseph stephen "caraps" s.': 212,
#  'palma, wilter  "sharky" ii wee': 213,
#  'pancho, gavini "apol" c.': 214,
#  'panotes, marisol c.': 215,
#  'peña, romulo jr.  "kid"': 216,
#  'pichay, prospero jr. a.': 217,
#  'pimentel, johnny ty': 218,
#  'pineda, enrico a.': 219,
#  'plaza, eddiebong g.': 220,
#  'puno, roberto v.': 221,
#  'quimbo, stella luz a.': 222,
#  'radaza, paz c.': 223,
#  'ramirez-sato, josephine': 224,
#  'ramos, ma. bernardita  "ditas"  b.': 225,
#  'remulla, jesus crispin c.': 226,
#  'revilla, strike b.': 227,
#  'reyes, allan benedict s.': 228,
#  'rivera, domingo c.': 229,
#  'robes, florida "rida" p.': 230,
#  'rodriguez, rufus b.': 231,
#  'roman, geraldine b.': 232,
#  'romero, michael  l., ph.d.': 233,
#  'romualdez, ferdinand martin g.': 234,
#  'romualdez, yedda marie k.': 235,
#  'romualdo, xavier jesus d.': 236,
#  'romulo, roman t.': 237,
#  'roque, rogelio neil p.': 238,
#  'sacdalan, joselito "joel" s.': 239,
#  'sagarbarria, manuel t.': 240,
#  'sakaluran, princess  rihan m.': 241,
#  'salceda, joey sarte': 242,
#  'salimbangon, janice z.': 243,
#  'salo, ron p.': 244,
#  'salvador-tambunting, joy myra': 245,
#  'sanchez, hector s.': 246,
#  'sangcopan, amihilda j.': 247,
#  'santos-recto, vilma': 248,
#  'sarmiento, edgar mary s.': 249,
#  'saulog, irene gay f.': 250,
#  'savellano, deogracias victor "dv" b.': 251,
#  'siao, frederick w.': 252,
#  'silverio, lorna c.': 253,
#  'singson, jose jr. "bonito" c.': 254,
#  'singson-meehan, kristine': 255,
#  'sinsuat, datu roonie sr. q.': 256,
#  'suansing, estrellita b.': 257,
#  'suansing, horacio jr. p.': 258,
#  'suarez, aleta c.': 259,
#  'suarez, david "jay-jay" c.': 260,
#  'suntay, jesus "bong" c.': 261,
#  'sy-alvarado, "kuya" jose antonio r.': 262,
#  'taduran, rowena niña o.': 263,
#  'tallado, josefina b.': 264,
#  'tan, alyssa sheena p.': 265,
#  'tan, angelina "helen" d.l., m.d.': 266,
#  'tan, samier a.': 267,
#  'tan, sharee ann t.': 268,
#  'tan, shernee a.': 269,
#  'tejada, jose "ping-ping" i.': 270,
#  'teves, arnolfo jr. "arnie" a.': 271,
#  'teves, jose jr. "bong" j.': 272,
#  'tiangco, john reynald m.': 273,
#  'tolentino, abraham "bambol" n.': 274,
#  'torres-gomez, lucy': 275,
#  'tulfo, jocelyn p.': 276,
#  'tupas, raul "boboy" c.': 277,
#  'tutor, kristine alexie b.': 278,
#  'ty, allan u.': 279,
#  'ty, diego "nonoy" c.': 280,
#  'umali, alfonso jr. v.': 281,
#  'umali, ma. victoria v.': 282,
#  'unabia, christian s.': 283,
#  'ungab, isidro t.': 284,
#  'uy, juliette t.': 285,
#  'uy, rolando "klarex" a.': 286,
#  'valeriano, rolando m.': 287,
#  'valmayor, gerardo jr. p.': 288,
#  'vargas, alfred d.': 289,
#  'velasco, lord allan jay q.': 290,
#  'veloso, vicente iii "ching" s.e.': 291,
#  'vergara, rosanna "ria" v.': 292,
#  'villa, jake vincent': 293,
#  'villafuerte, luis raymund  jr. "lray" f.': 294,
#  'villanueva, eduardo "bro. eddie" c.': 295,
#  'villanueva, noel l.': 296,
#  'villar, camille a.': 297,
#  'villaraza-suarez, anna marie': 298,
#  'villarica, henry r.': 299,
#  'violago, micaela s.': 300,
#  'yap, eric go': 301,
#  'yap, victor a.': 302,
#  'yu, divina grace c.': 303,
#  'zamora, manuel "way kurat" e.': 304,
#  'zamora, ronaldo b.': 305,
#  'zarate, carlos isagani t.': 306,
#  'zubiri, manuel f.': 307}

# %% [markdown]
# Import the model used to compare strings for similarity - cosine similarity.

# %%
from strsimpy.cosine import Cosine
cosine = Cosine(2)

# %% [markdown]
# The `associate_authors` function takes as input a list of authors, the mapping between authors and their integer, their cosine vectors and the similarity module.
#
# This function associates the comma-delimited list of authors associated with a single bill to a representative - either an exact match or one that needs to be computed for by obtaining the string closest to each author.
#
# The `closest_match` function computes for the similarity score between each HoR member and the author string. The HoR member with the greatest similarity profile value is obtained and associated with the author string.

# %%
def closest_match(rep_vec, rep_names, author, model, out, verbose=False):
    # inefficient - sort as binary tree, find insertion and survey neighboring nodes more efficient
    '''
    get name of representative closest to input
    - perform cosine similarity if no exact match
        - if entry it is most similar to has already been classified, get next best until one is found
    - return exact match otherwise
    '''
    assert(type(model) is not Cosine or type(rep_vec) is dict)
    rep_score = []
    for rep in rep_names.keys():
        if type(model) is Cosine:
            rep_score.append((rep, 1-model.similarity_profiles(model.get_profile(author), rep_vec[rep])))
        else:
            rep_score.append((rep, model.distance(author, rep)))
    reps_sorted_scores = sorted(rep_score, key=lambda x: x[1])
    for i in range(len(rep_score)):
        if out.get(rep_names[reps_sorted_scores[i][0]], None) is None:
            if verbose:
                print(reps_sorted_scores[i], author)
            return reps_sorted_scores[i][0]

def associate_authors(authors_str, rep_names, vectorized_reps, model, verbose=False):
    '''
    get name of representative closest to input
    - perform cosine similarity if no exact match
    - return exact match otherwise
    '''
    out = {}
    author_li = authors_str.lower().split(';')
    second_pass = []
    for author in author_li:
        author = author.strip()
        if author == '':
            continue
        # if author is an exact match to key and not yet classified
        if author in rep_names and rep_names[author] not in out:
            out[rep_names[author]]=1
        # if author is not an exact match to key OR was classified already,
        # save for second pass
        else:
            second_pass.append(author)
    
    for author in second_pass:
        author_match = closest_match(vectorized_reps, rep_names, author, model, out, verbose=verbose)
        out[rep_names[author_match]] = 1
    return list(out.keys())

# %% [markdown]
# Test `associate_authors` on one entry. The similarity score of each string passed to the `closest_match` function is shown below together with the string with best match.

# %%
vectorized_reps = {x:cosine.get_profile(x) for x in rep_names}
out = associate_authors(bills_df['Principal Author/s'].iloc[10787], rep_names, vectorized_reps, cosine, verbose=True)
len(out)
# Out:
# ('zamora, manuel "way kurat" e.', 0.26843647904971013) zamora, way kurat
# ('villafuerte, luis raymund  jr. "lray" f.', 0.03607461457624028) villafuerte, luis raymund "lray" jr f.
# ('pacquiao, rogelio "ruel" d.', 0.13289003047588022) pacquiao, rogelio d.
# ('momo, romeo sr. s.', 0.0897008726364874) momo, romeo s.
# ('pacquiao, alberto "bobby" d.', 0.16112950719213903) pacquiao, alberto d.
# ('palma, wilter  "sharky" ii wee', 0.0) palma, wilter "sharky" ii wee
# 34

# %% [markdown]
# Apply the function to each bill to associate a list of HoR authors with them. Its progress can be seen below.

# %%
from tqdm.notebook import tqdm
from functools import partial

bills_df['Principal Author/s'] = bills_df['Principal Author/s'].fillna('')

const_func = partial(associate_authors, rep_names=rep_names, model=cosine, vectorized_reps=vectorized_reps)
bills_df['indiv_cong'] = list(tqdm(map(const_func, bills_df['Principal Author/s'].to_list()), total=len(bills_df)))
# Out:
#   0%|          | 0/10821 [00:00<?, ?it/s]

# %% [markdown]
# Expected runtime: ~2-2.5 minutes

# %% [markdown]
# Check for missed values - validate that all authors present in the `Principal Author/s` field are mapped to an HoR member.

# %%
bills_df['identified_tot'] = bills_df['indiv_cong'].map(lambda x: len(x))
newdf = bills_df[bills_df['identified_tot'] != bills_df['Author Count']]
(newdf['Author Count'] - newdf['identified_tot']).value_counts()
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Compare authors and associated HoR members visually.

# %%
bills_df['Principal Author/s'], bills_df['indiv_cong'].map(lambda x: ';'.join([num_to_rep[cong] for cong in x]))
# Out:
# (0        UNGAB, ISIDRO T.;CAYETANO, ALAN PETER "COMPAÑE...
#  1        DUTERTE, PAOLO Z.;CAYETANO, MARIA LAARNI;CAYET...
#  2                      CAYETANO, ALAN PETER "COMPAÑERO" S.
#  3        DUTERTE, PAOLO Z.;CAYETANO, ALAN PETER "COMPAÑ...
#  4                      CAYETANO, ALAN PETER "COMPAÑERO" S.
#                                 ...
#  10817                                  RODRIGUEZ, RUFUS B.
#  10818                                  RODRIGUEZ, RUFUS B.
#  10819                                    CARDEMA, DUCIELLE
#  10820    FERNANDEZ, DAN S.;CAYETANO, ALAN PETER "COMPAÑ...
#  10821                                    CARDEMA, DUCIELLE
#  Name: Principal Author/s, Length: 10821, dtype: object,
#  0        ungab, isidro t.;cayetano, alan peter "compañe...
#  1        duterte, paolo z.;cayetano, maria laarni;cayet...
#  2                      cayetano, alan peter "compañero" s.
#  3        duterte, paolo z.;cayetano, alan peter "compañ...
#  4                      cayetano, alan peter "compañero" s.
#                                 ...
#  10817                                  rodriguez, rufus b.
#  10818                                  rodriguez, rufus b.
#  10819                           cardema, ducielle marie s.
#  10820    fernandez, dan s.;cayetano, alan peter "compañ...
#  10821                           cardema, ducielle marie s.
#  Name: indiv_cong, Length: 10821, dtype: object)

# %% [markdown]
# See the notation used to associate each HoR representative - an integer corresponding to its index in `reps_df`.

# %%
bills_df['indiv_cong']
# Out:
# 0               [284, 72, 180]
# 1                [104, 73, 72]
# 2                         [72]
# 3                    [104, 72]
# 4                         [72]
#                  ...
# 10817                    [231]
# 10818                    [231]
# 10819                     [67]
# 10820    [121, 72, 3, 73, 294]
# 10821                     [67]
# Name: indiv_cong, Length: 10821, dtype: object

# %% [markdown]
# ## Creating Features

# %%
import numpy as np

# %%
reps_df
# Out:
#                               rep_name         rep_region rep_subdistrict  \
# 0            Abante, Bienvenido Jr. M.             Manila    6th District
# 1      Abaya, Francis Gerald Aguinaldo             Cavite    1st District
# 2               Abellanosa, Rodrigo A.          Cebu City    2nd District
# 3                Abu, Raneo "Ranie" E.           Batangas    2nd District
# 4    Abueg-Zaldivar, Cyrille "Beng" F.            Palawan    2nd District
# ..                                 ...                ...             ...
# 303                Yu, Divina Grace C.  Zamboanga del Sur    1st District
# 304      Zamora, Manuel "Way Kurat" E.       Davao de Oro    1st District
# 305                 Zamora, Ronaldo B.      San Juan City   Lone District
# 306          Zarate, Carlos Isagani T.                NaN             NaN
# 307                  Zubiri, Manuel F.           Bukidnon    3rd District
#
#       partylist            link                             name   party  \
# 0           NaN        abante-b   ABANTE, BIENVENIDO JR. MIRANDO  ASENSO
# 1           NaN        abaya-fg  ABAYA, FRANCIS GERALD AGUINALDO      LP
# 2           NaN    abellanosa-r     ABELLANOSA, RODRIGO ABELLANA     LDP
# 3           NaN           abu-r              ABU, RANEO ENRIQUEZ      NP
# 4           NaN  abueg-zaldivar           ABUEG, CYRILLE FABELLO     PPP
# ..          ...             ...                              ...     ...
# 303         NaN            yu-d         YU, DIVINA GRACE CABARDO  PDPLBN
# 304         NaN        zamora-m          ZAMORA, MANUEL ESQUIVEL     HNP
# 305         NaN        zamora-r            ZAMORA, RONALDO BAYAN  PDPLBN
# 306  BAYAN MUNA        zarate-c                              NaN     NaN
# 307         NaN        zubiri-m         ZUBIRI, MANUEL FERNANDEZ     BPP
#
#        votes    conf_date       district                   region  \
# 0     49,795  14-May-2019   6th District  NATIONAL CAPITAL REGION
# 1    117,031  16-May-2019   1st District              REGION IV-A
# 2    163,752  15-May-2019   2nd District               REGION VII
# 3    117,205  16-May-2019   2nd District              REGION IV-A
# 4    112,960  17-May-2019   2nd District              REGION IV-B
# ..       ...          ...            ...                      ...
# 303  164,990  18-May-2019   1st District                REGION IX
# 304   78,257  17-May-2019   1st District                REGION XI
# 305   35,386  13-May-2019  Lone District  NATIONAL CAPITAL REGION
# 306      NaN          NaN            NaN                      NaN
# 307  136,768  18-May-2019   3rd District                 REGION X
#
#            subdistrict
# 0               Manila
# 1               Cavite
# 2            Cebu City
# 3             Batangas
# 4              Palawan
# ..                 ...
# 303  Zamboanga del Sur
# 304       Davao de Oro
# 305      San Juan City
# 306                NaN
# 307           Bukidnon
#
# [308 rows x 12 columns]

# %% [markdown]
# Decompose the list of authors associated with each bill as a one-to-many relationship.

# %%
bill_to_author = pd.DataFrame({'ID':np.repeat(bills_df.ID.values, bills_df.indiv_cong.str.len()),
                        'author_id':np.concatenate(bills_df.indiv_cong.values)})
bill_to_author
# Out:
#             ID  author_id
# 0      HB00001        284
# 1      HB00001         72
# 2      HB00001        180
# 3      HB00002        104
# 4      HB00002         73
# ...        ...        ...
# 40807  HB10832         72
# 40808  HB10832          3
# 40809  HB10832         73
# 40810  HB10832        294
# 40811  HB10833         67
#
# [40812 rows x 2 columns]

# %% [markdown]
# Inner join the `reps_df` with `bills_df`, associating the authors' details with each bill as well.

# %%
reps_df['author_id'] = range(len(reps_df))
reps_df = reps_df.drop('author_id', axis=1)
bill_to_author_df = bill_to_author.join(reps_df, on='author_id', how='inner')
bill_to_author_df
# Out:
#             ID  author_id                    rep_name  rep_region  \
# 0      HB00001        284            Ungab, Isidro T.  Davao City
# 948    HB00497        284            Ungab, Isidro T.  Davao City
# 1429   HB00861        284            Ungab, Isidro T.  Davao City
# 1687   HB01061        284            Ungab, Isidro T.  Davao City
# 1709   HB01079        284            Ungab, Isidro T.  Davao City
# ...        ...        ...                         ...         ...
# 18930  HB08231         67  Cardema, Ducielle Marie S.         NaN
# 26745  HB09411         67  Cardema, Ducielle Marie S.         NaN
# 33805  HB10153         67  Cardema, Ducielle Marie S.         NaN
# 40805  HB10831         67  Cardema, Ducielle Marie S.         NaN
# 40811  HB10833         67  Cardema, Ducielle Marie S.         NaN
#
#       rep_subdistrict      partylist       link               name party  \
# 0        3rd District            NaN    ungab-i  UNGAB, ISIDRO TOM   HNP
# 948      3rd District            NaN    ungab-i  UNGAB, ISIDRO TOM   HNP
# 1429     3rd District            NaN    ungab-i  UNGAB, ISIDRO TOM   HNP
# 1687     3rd District            NaN    ungab-i  UNGAB, ISIDRO TOM   HNP
# 1709     3rd District            NaN    ungab-i  UNGAB, ISIDRO TOM   HNP
# ...               ...            ...        ...                ...   ...
# 18930             NaN  DUTERTE YOUTH  cardema-d                NaN   NaN
# 26745             NaN  DUTERTE YOUTH  cardema-d                NaN   NaN
# 33805             NaN  DUTERTE YOUTH  cardema-d                NaN   NaN
# 40805             NaN  DUTERTE YOUTH  cardema-d                NaN   NaN
# 40811             NaN  DUTERTE YOUTH  cardema-d                NaN   NaN
#
#          votes    conf_date      district     region subdistrict
# 0      160,732  14-May-2019  3rd District  REGION XI  Davao City
# 948    160,732  14-May-2019  3rd District  REGION XI  Davao City
# 1429   160,732  14-May-2019  3rd District  REGION XI  Davao City
# 1687   160,732  14-May-2019  3rd District  REGION XI  Davao City
# 1709   160,732  14-May-2019  3rd District  REGION XI  Davao City
# ...        ...          ...           ...        ...         ...
# 18930      NaN          NaN           NaN        NaN         NaN
# 26745      NaN          NaN           NaN        NaN         NaN
# 33805      NaN          NaN           NaN        NaN         NaN
# 40805      NaN          NaN           NaN        NaN         NaN
# 40811      NaN          NaN           NaN        NaN         NaN
#
# [40812 rows x 14 columns]

# %%
bill_to_author_df.columns
# Out:
# Index(['ID', 'author_id', 'rep_name', 'rep_region', 'rep_subdistrict',
#        'partylist', 'link', 'name', 'party', 'votes', 'conf_date', 'district',
#        'region', 'subdistrict'],
#       dtype='object')

# %% [markdown]
# Inspect the unique values of each field.

# %%
bill_to_author_df.region.unique()
# Out:
# array(['REGION XI', 'NATIONAL CAPITAL REGION', 'REGION IV-B',
#        'REGION VII', 'REGION V', 'REGION VI', 'REGION II', nan,
#        'REGION III', 'REGION I', 'CORDILLERA ADMINISTRATIVE REGION',
#        'REGION XIII', 'REGION IV-A', 'REGION IX', 'REGION X',
#        'REGION VIII', 'REGION XII', 'BARMM'], dtype=object)

# %%
un = bill_to_author_df.partylist.unique()
un, len(un)
# Out:
# (array([nan, 'MAGDALO', 'AKO BICOL', 'ANG PROBINSYANO', 'AAMBIS-OWA',
#         'GMA', 'MANILA TEACHERS', 'AKO PADAYON PILIPINO', 'ANAKALUSUGAN',
#         'ATROL', '1-PACMAN', 'BH', 'KABAYAN', 'ACT-CIS', 'BA', 'AMIN',
#         'DIWA', 'AN WARAY', 'BAHAY', 'TINGOG SINIRANGAN', 'ALONA', 'SAGIP',
#         'AKO BISAYA', 'ACT-TEACHERS', 'ABANG LINGKOD', 'KABATAAN',
#         'BAYAN MUNA', 'GABRIELA', 'HILRECA', 'RECOBODA', 'APEC',
#         'MAGSASAKA', 'CIBAC', 'ROBINSYANO AKO', 'BHW', 'KALINGA', 'MARINO',
#         'TUCP', 'ABONO', 'A TEACHER', 'BUHAY', 'KUSUG TAUSUG', 'GP', 'RAM',
#         'CWS', 'COOP-NATCCO', 'DUMPER PTDA', 'TGP', 'AGAP', 'OFW FAMILY',
#         'SENIOR CITIZENS', 'DUTERTE YOUTH'], dtype=object),
#  52)

# %%
un = bill_to_author_df.party.unique()
(un, len(un))
# Out:
# (array(['HNP', 'NP', 'HTL', 'LP', 'NPC', 'PDPLBN', nan, 'PDP–Laban',
#         'BILEG', 'LAKAS', 'NUP', 'NVTEÑO', 'PFP', 'BPP', 'CDP', 'KABAKA',
#         'PPP', 'LDP', 'AKSYON', 'PRP', 'PMP', 'ASENSO', 'IND', 'APP'],
#        dtype=object),
#  24)

# %% [markdown]
# Create a column to indicate whether the representative associated with a bill is a Partylist representative.

# %%
bill_to_author_df['is_partylist'] = ~bill_to_author_df['partylist'].isna()
bill_to_author_df = bill_to_author_df.drop(['link', 'name', 'conf_date'], axis=1)
bill_to_author_df
# Out:
#             ID  author_id                    rep_name  rep_region  \
# 0      HB00001        284            Ungab, Isidro T.  Davao City
# 948    HB00497        284            Ungab, Isidro T.  Davao City
# 1429   HB00861        284            Ungab, Isidro T.  Davao City
# 1687   HB01061        284            Ungab, Isidro T.  Davao City
# 1709   HB01079        284            Ungab, Isidro T.  Davao City
# ...        ...        ...                         ...         ...
# 18930  HB08231         67  Cardema, Ducielle Marie S.         NaN
# 26745  HB09411         67  Cardema, Ducielle Marie S.         NaN
# 33805  HB10153         67  Cardema, Ducielle Marie S.         NaN
# 40805  HB10831         67  Cardema, Ducielle Marie S.         NaN
# 40811  HB10833         67  Cardema, Ducielle Marie S.         NaN
#
#       rep_subdistrict      partylist party    votes      district     region  \
# 0        3rd District            NaN   HNP  160,732  3rd District  REGION XI
# 948      3rd District            NaN   HNP  160,732  3rd District  REGION XI
# 1429     3rd District            NaN   HNP  160,732  3rd District  REGION XI
# 1687     3rd District            NaN   HNP  160,732  3rd District  REGION XI
# 1709     3rd District            NaN   HNP  160,732  3rd District  REGION XI
# ...               ...            ...   ...      ...           ...        ...
# 18930             NaN  DUTERTE YOUTH   NaN      NaN           NaN        NaN
# 26745             NaN  DUTERTE YOUTH   NaN      NaN           NaN        NaN
# 33805             NaN  DUTERTE YOUTH   NaN      NaN           NaN        NaN
# 40805             NaN  DUTERTE YOUTH   NaN      NaN           NaN        NaN
# 40811             NaN  DUTERTE YOUTH   NaN      NaN           NaN        NaN
#
#       subdistrict  is_partylist
# 0      Davao City         False
# 948    Davao City         False
# 1429   Davao City         False
# 1687   Davao City         False
# 1709   Davao City         False
# ...           ...           ...
# 18930         NaN          True
# 26745         NaN          True
# 33805         NaN          True
# 40805         NaN          True
# 40811         NaN          True
#
# [40812 rows x 12 columns]

# %% [markdown]
# Drop unneeded columns and rename for clarity.

# %%
bill_to_author_df = bill_to_author_df.drop(['rep_region', 'rep_subdistrict'], axis=1)
bill_to_author_df = bill_to_author_df.rename({'subdistrict': 'province'}, axis=1)

# %%
bill_to_author_df['party'] = bill_to_author_df['party'].fillna(bill_to_author_df['partylist'])
bill_to_author_df = bill_to_author_df.drop(['partylist', 'votes'], axis=1)
bill_to_author_df
# Out:
#             ID  author_id                    rep_name          party  \
# 0      HB00001        284            Ungab, Isidro T.            HNP
# 948    HB00497        284            Ungab, Isidro T.            HNP
# 1429   HB00861        284            Ungab, Isidro T.            HNP
# 1687   HB01061        284            Ungab, Isidro T.            HNP
# 1709   HB01079        284            Ungab, Isidro T.            HNP
# ...        ...        ...                         ...            ...
# 18930  HB08231         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 26745  HB09411         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 33805  HB10153         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 40805  HB10831         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 40811  HB10833         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
#
#            district     region    province  is_partylist
# 0      3rd District  REGION XI  Davao City         False
# 948    3rd District  REGION XI  Davao City         False
# 1429   3rd District  REGION XI  Davao City         False
# 1687   3rd District  REGION XI  Davao City         False
# 1709   3rd District  REGION XI  Davao City         False
# ...             ...        ...         ...           ...
# 18930           NaN        NaN         NaN          True
# 26745           NaN        NaN         NaN          True
# 33805           NaN        NaN         NaN          True
# 40805           NaN        NaN         NaN          True
# 40811           NaN        NaN         NaN          True
#
# [40812 rows x 8 columns]

# %%
bill_to_author_df = bill_to_author_df.drop(['district'], axis=1)
bill_to_author_df
# Out:
#             ID  author_id                    rep_name          party  \
# 0      HB00001        284            Ungab, Isidro T.            HNP
# 948    HB00497        284            Ungab, Isidro T.            HNP
# 1429   HB00861        284            Ungab, Isidro T.            HNP
# 1687   HB01061        284            Ungab, Isidro T.            HNP
# 1709   HB01079        284            Ungab, Isidro T.            HNP
# ...        ...        ...                         ...            ...
# 18930  HB08231         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 26745  HB09411         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 33805  HB10153         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 40805  HB10831         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 40811  HB10833         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
#
#           region    province  is_partylist
# 0      REGION XI  Davao City         False
# 948    REGION XI  Davao City         False
# 1429   REGION XI  Davao City         False
# 1687   REGION XI  Davao City         False
# 1709   REGION XI  Davao City         False
# ...          ...         ...           ...
# 18930        NaN         NaN          True
# 26745        NaN         NaN          True
# 33805        NaN         NaN          True
# 40805        NaN         NaN          True
# 40811        NaN         NaN          True
#
# [40812 rows x 7 columns]

# %% [markdown]
# Create dataset for exploratory data analysis.

# %%
bill_to_author_df_eda = bills_df.set_index('ID').join(bill_to_author_df.set_index('ID'), on='ID', how='right')
bill_to_author_df_eda.to_csv('congress_bill_association_eda.csv', encoding='utf-8', index=False)
bill_to_author_df_eda
# Out:
#         Significance  Date Filed  \
# ID
# HB00001     National  2019-07-01
# HB00497        Local  2019-07-01
# HB00861        Local  2019-07-01
# HB01061        Local  2019-07-02
# HB01079        Local  2019-07-02
# ...              ...         ...
# HB08231     National  2020-12-14
# HB09411     National  2021-05-24
# HB10153     National  2021-09-07
# HB10831          NaN  2022-03-29
# HB10833          NaN  2022-04-11
#
#                                                 Full Title  \
# ID
# HB00001  AN ACT INSTITUTIONALIZING A NATIONAL VALUES, E...
# HB00497  AN ACT PROVIDING FOR THE CONSTRUCTION OF A CIR...
# HB00861  AN ACT CREATING A REGULAR LTO DISTRICT OFFICE ...
# HB01061  AN ACT CONVERTING THE STA. IGNACIA – GUIMBA PR...
# HB01079  AN ACT MANDATING THE CONSTRUCTION OF A COASTAL...
# ...                                                    ...
# HB08231  AN ACT TO OUTLAW THE COMMUNIST PARTY OF THE PH...
# HB09411  AN ACT\nPROVIDING FOR ADDITIONAL MECHANISMS TO...
# HB10153  AN ACT APPROPRIATING FUNDS FOR THE OPERATION O...
# HB10831  AN ACT POSTPONING THE DECEMBER 2022 BARANGAY A...
# HB10833  AN ACT RENAMING THE NINOY AQUINO INTERNATIONAL...
#
#                                         Principal Author/s   Date Read  \
# ID
# HB00001  UNGAB, ISIDRO T.;CAYETANO, ALAN PETER "COMPAÑE...  2019-07-23
# HB00497  DEL MAR, RAUL V.;UNGAB, ISIDRO T.;MADRONA. ELE...  2019-07-23
# HB00861  HERNANDEZ, FERDINAND L.;UNGAB, ISIDRO T.;SARMI...  2019-07-23
# HB01061  YAP, VICTOR A.;UNGAB, ISIDRO T.;MADRONA. ELEAN...  2019-07-24
# HB01079  UNGAB, ISIDRO T.;SY-ALVARADO, "KUYA" JOSE ANTO...  2019-07-24
# ...                                                    ...         ...
# HB08231                                  CARDEMA, DUCIELLE  2020-12-16
# HB09411  FUENTEBELLA, ARNIE B.;SAKALURAN, PRINCESS RIHA...  2021-05-24
# HB10153  FRASCO, VINCENT FRANCO "DUKE" D.;VILLANUEVA, N...  2021-09-07
# HB10831                                  CARDEMA, DUCIELLE         NaN
# HB10833                                  CARDEMA, DUCIELLE         NaN
#
#                       Primary Referral  \
# ID
# HB00001    BASIC EDUCATION AND CULTURE
# HB00497      PUBLIC WORKS AND HIGHWAYS
# HB00861                 TRANSPORTATION
# HB01061      PUBLIC WORKS AND HIGHWAYS
# HB01079      PUBLIC WORKS AND HIGHWAYS
# ...                                ...
# HB08231  NATIONAL DEFENSE AND SECURITY
# HB09411               ECONOMIC AFFAIRS
# HB10153                 APPROPRIATIONS
# HB10831                            NaN
# HB10833                            NaN
#
#                                                Bill Status  \
# ID
# HB00001                             Substituted by HB05829
# HB00497  Approved by the House on 2020-02-26, transmitt...
# HB00861         Transmitted to the President on 2022-03-11
# HB01061         Republic Act RA11483 enacted on 2020-08-14
# HB01079  Approved by the House on 2020-02-26, transmitt...
# ...                                                    ...
# HB08231  Pending with the Committee on NATIONAL DEFENSE...
# HB09411  Approved by the House on 2021-06-01, transmitt...
# HB10153         Republic Act RA11639 enacted on 2021-12-30
# HB10831      Pending First Reading (Filed last 2022-03-29)
# HB10833      Pending First Reading (Filed last 2022-04-11)
#
#                                  Mother Bill Status  \
# ID
# HB00001  Republic Act RA11476 enacted on 2020-06-25
# HB00497                                         NaN
# HB00861                                         NaN
# HB01061                                         NaN
# HB01079                                         NaN
# ...                                             ...
# HB08231                                         NaN
# HB09411                                         NaN
# HB10153                                         NaN
# HB10831                                         NaN
# HB10833                                         NaN
#
#         Date Approved on Second Reading Date Approved on Third Reading  ...  \
# ID                                                                      ...
# HB00001                             NaN                            NaN  ...
# HB00497                      2020-02-18                     2020-02-26  ...
# HB00861                      2019-11-06                     2019-11-12  ...
# HB01061                      2019-12-18                     2020-01-27  ...
# HB01079                      2020-02-18                     2020-02-26  ...
# ...                                 ...                            ...  ...
# HB08231                             NaN                            NaN  ...
# HB09411                      2021-05-25                     2021-06-01  ...
# HB10153                      2021-09-30                     2021-09-30  ...
# HB10831                             NaN                            NaN  ...
# HB10833                             NaN                            NaN  ...
#
#         Republic Act No. Author Count  \
# ID
# HB00001              NaN            3
# HB00497              NaN            3
# HB00861              NaN            3
# HB01061          RA11483            3
# HB01079              NaN            3
# ...                  ...          ...
# HB08231              NaN            1
# HB09411              NaN          288
# HB10153              NaN          120
# HB10831              NaN            1
# HB10833              NaN            1
#
#                                                 indiv_cong  identified_tot  \
# ID
# HB00001                                     [284, 72, 180]               3
# HB00497                                     [96, 284, 180]               3
# HB00861                                    [154, 284, 249]               3
# HB01061                                    [302, 284, 180]               3
# HB01079                                    [284, 262, 180]               3
# ...                                                    ...             ...
# HB08231                                               [67]               1
# HB09411  [130, 147, 155, 270, 185, 134, 41, 78, 55, 165...             288
# HB10153  [296, 194, 130, 43, 147, 152, 240, 270, 36, 77...             120
# HB10831                                               [67]               1
# HB10833                                               [67]               1
#
#         author_id                    rep_name          party     region  \
# ID
# HB00001       284            Ungab, Isidro T.            HNP  REGION XI
# HB00497       284            Ungab, Isidro T.            HNP  REGION XI
# HB00861       284            Ungab, Isidro T.            HNP  REGION XI
# HB01061       284            Ungab, Isidro T.            HNP  REGION XI
# HB01079       284            Ungab, Isidro T.            HNP  REGION XI
# ...           ...                         ...            ...        ...
# HB08231        67  Cardema, Ducielle Marie S.  DUTERTE YOUTH        NaN
# HB09411        67  Cardema, Ducielle Marie S.  DUTERTE YOUTH        NaN
# HB10153        67  Cardema, Ducielle Marie S.  DUTERTE YOUTH        NaN
# HB10831        67  Cardema, Ducielle Marie S.  DUTERTE YOUTH        NaN
# HB10833        67  Cardema, Ducielle Marie S.  DUTERTE YOUTH        NaN
#
#            province is_partylist
# ID
# HB00001  Davao City        False
# HB00497  Davao City        False
# HB00861  Davao City        False
# HB01061  Davao City        False
# HB01079  Davao City        False
# ...             ...          ...
# HB08231         NaN         True
# HB09411         NaN         True
# HB10153         NaN         True
# HB10831         NaN         True
# HB10833         NaN         True
#
# [40812 rows x 22 columns]

# %% [markdown]
# One-hot encode political parties for each candidate.

# %%
cols = pd.get_dummies(bill_to_author_df['party'].str.lower().replace('-','_').replace(' ', '_'), prefix='party')
cols
# Out:
#        party_1-pacman  party_a teacher  party_aambis-owa  party_abang lingkod  \
# 0                   0                0                 0                    0
# 948                 0                0                 0                    0
# 1429                0                0                 0                    0
# 1687                0                0                 0                    0
# 1709                0                0                 0                    0
# ...               ...              ...               ...                  ...
# 18930               0                0                 0                    0
# 26745               0                0                 0                    0
# 33805               0                0                 0                    0
# 40805               0                0                 0                    0
# 40811               0                0                 0                    0
#
#        party_abono  party_act-cis  party_act-teachers  party_agap  \
# 0                0              0                   0           0
# 948              0              0                   0           0
# 1429             0              0                   0           0
# 1687             0              0                   0           0
# 1709             0              0                   0           0
# ...            ...            ...                 ...         ...
# 18930            0              0                   0           0
# 26745            0              0                   0           0
# 33805            0              0                   0           0
# 40805            0              0                   0           0
# 40811            0              0                   0           0
#
#        party_ako bicol  party_ako bisaya  ...  party_ppp  party_prp  \
# 0                    0                 0  ...          0          0
# 948                  0                 0  ...          0          0
# 1429                 0                 0  ...          0          0
# 1687                 0                 0  ...          0          0
# 1709                 0                 0  ...          0          0
# ...                ...               ...  ...        ...        ...
# 18930                0                 0  ...          0          0
# 26745                0                 0  ...          0          0
# 33805                0                 0  ...          0          0
# 40805                0                 0  ...          0          0
# 40811                0                 0  ...          0          0
#
#        party_ram  party_recoboda  party_robinsyano ako  party_sagip  \
# 0              0               0                     0            0
# 948            0               0                     0            0
# 1429           0               0                     0            0
# 1687           0               0                     0            0
# 1709           0               0                     0            0
# ...          ...             ...                   ...          ...
# 18930          0               0                     0            0
# 26745          0               0                     0            0
# 33805          0               0                     0            0
# 40805          0               0                     0            0
# 40811          0               0                     0            0
#
#        party_senior citizens  party_tgp  party_tingog sinirangan  party_tucp
# 0                          0          0                        0           0
# 948                        0          0                        0           0
# 1429                       0          0                        0           0
# 1687                       0          0                        0           0
# 1709                       0          0                        0           0
# ...                      ...        ...                      ...         ...
# 18930                      0          0                        0           0
# 26745                      0          0                        0           0
# 33805                      0          0                        0           0
# 40805                      0          0                        0           0
# 40811                      0          0                        0           0
#
# [40812 rows x 74 columns]

# %% [markdown]
# Add the one-hot encoded party columns to the original dataset.

# %%
bill_to_author_df = bill_to_author_df.join(cols, how='inner')
bill_to_author_df
# Out:
#             ID  author_id                    rep_name          party  \
# 0      HB00001        284            Ungab, Isidro T.            HNP
# 948    HB00497        284            Ungab, Isidro T.            HNP
# 1429   HB00861        284            Ungab, Isidro T.            HNP
# 1687   HB01061        284            Ungab, Isidro T.            HNP
# 1709   HB01079        284            Ungab, Isidro T.            HNP
# ...        ...        ...                         ...            ...
# 18930  HB08231         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 26745  HB09411         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 33805  HB10153         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 40805  HB10831         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 40811  HB10833         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
#
#           region    province  is_partylist  party_1-pacman  party_a teacher  \
# 0      REGION XI  Davao City         False               0                0
# 948    REGION XI  Davao City         False               0                0
# 1429   REGION XI  Davao City         False               0                0
# 1687   REGION XI  Davao City         False               0                0
# 1709   REGION XI  Davao City         False               0                0
# ...          ...         ...           ...             ...              ...
# 18930        NaN         NaN          True               0                0
# 26745        NaN         NaN          True               0                0
# 33805        NaN         NaN          True               0                0
# 40805        NaN         NaN          True               0                0
# 40811        NaN         NaN          True               0                0
#
#        party_aambis-owa  ...  party_ppp  party_prp  party_ram  party_recoboda  \
# 0                     0  ...          0          0          0               0
# 948                   0  ...          0          0          0               0
# 1429                  0  ...          0          0          0               0
# 1687                  0  ...          0          0          0               0
# 1709                  0  ...          0          0          0               0
# ...                 ...  ...        ...        ...        ...             ...
# 18930                 0  ...          0          0          0               0
# 26745                 0  ...          0          0          0               0
# 33805                 0  ...          0          0          0               0
# 40805                 0  ...          0          0          0               0
# 40811                 0  ...          0          0          0               0
#
#        party_robinsyano ako  party_sagip  party_senior citizens  party_tgp  \
# 0                         0            0                      0          0
# 948                       0            0                      0          0
# 1429                      0            0                      0          0
# 1687                      0            0                      0          0
# 1709                      0            0                      0          0
# ...                     ...          ...                    ...        ...
# 18930                     0            0                      0          0
# 26745                     0            0                      0          0
# 33805                     0            0                      0          0
# 40805                     0            0                      0          0
# 40811                     0            0                      0          0
#
#        party_tingog sinirangan  party_tucp
# 0                            0           0
# 948                          0           0
# 1429                         0           0
# 1687                         0           0
# 1709                         0           0
# ...                        ...         ...
# 18930                        0           0
# 26745                        0           0
# 33805                        0           0
# 40805                        0           0
# 40811                        0           0
#
# [40812 rows x 81 columns]

# %% [markdown]
# Clean data by clarifying that "Taguig-Pateros" is the same as "Taguig" in terms of provincial districts.

# %%
bill_to_author_df.loc[bill_to_author_df['province']=='Taguig', 'province'] = 'Taguig-Pateros'
print(bill_to_author_df.province.unique(), len(bill_to_author_df.province.unique()))
# Out:
# ['Davao City' 'Taguig-Pateros' 'Romblon' 'Cebu City' 'Albay' 'Sorsogon'
#  'Muntinlupa City' 'Negros Occidental' 'Isabela' nan 'Tarlac'
#  'Camarines Sur' 'Valenzuela City' 'Manila' 'Negros Oriental' 'Masbate'
#  'Quirino' 'Ilocos Sur' 'Marikina City' 'Las Piñas City' 'Baguio City'
#  'Surigao del Sur' 'Cebu' 'Capiz' 'Batangas' 'Zamboanga del Sur'
#  'Quezon City' 'Camiguin' 'Iloilo' 'Parañaque City' 'Nueva Ecija'
#  'Iloilo City' 'Makati City' 'Cavite' 'Pasay City' 'Camarines Norte'
#  'Bohol' 'Navotas City' 'San Jose Del Monte City' 'Palawan' 'Leyte'
#  'Misamis Oriental' 'Siquijor' 'Bulacan' 'Sultan Kudarat' 'Bataan' 'Rizal'
#  'Sarangani' 'Pangasinan' 'Surigao del Norte' 'Northern Samar' 'Samar'
#  'Bukidnon' 'Agusan del Norte' 'Pampanga' 'Laguna' 'Zamboanga City'
#  'Cagayan de Oro City' 'Oriental Mindoro' 'Lapu-Lapu City' 'Malabon City'
#  'Zamboanga Sibugay' 'Ifugao' 'Agusan del Sur' 'Ilocos Norte' 'Quezon'
#  'Antipolo City' 'Occidental Mindoro' 'Zambales' 'Mountain Province'
#  'Maguindanao' 'Benguet' 'La Union' 'Nueva Vizcaya' 'Misamis Occidental'
#  'Davao de Oro' 'Caloocan City' 'Bacolod City' 'Kalinga' 'Pasig City'
#  'Aklan' 'Davao Oriental' 'Antique' 'Apayao' 'Cagayan'
#  'Zamboanga del Norte' 'South Cotabato' 'Batanes' 'Biliran' 'Calamba City'
#  'North Cotabato' 'Marinduque' 'Catanduanes' 'Sulu' 'Biñan City'
#  'Eastern Samar' 'Aurora' 'Basilan' 'Mandaluyong City' 'Iligan City'
#  'Dinagat Islands' 'Lanao del Norte' 'Davao del Norte' 'Lanao del Sur'
#  'Abra' 'Davao Occidental' 'Southern Leyte' 'Guimaras' 'San Juan City'
#  'Davao del Sur' 'Tawi-Tawi'] 111

# %% [markdown]
# One-hot encode region and province data for each candidate. Add the one-hot encoded region and province columns to the original dataset.

# %%
cols = pd.get_dummies(bill_to_author_df['province'].str.lower().str.replace(' ', '_'), prefix='province')
cols
# Out:
#        province_abra  province_agusan_del_norte  province_agusan_del_sur  \
# 0                  0                          0                        0
# 948                0                          0                        0
# 1429               0                          0                        0
# 1687               0                          0                        0
# 1709               0                          0                        0
# ...              ...                        ...                      ...
# 18930              0                          0                        0
# 26745              0                          0                        0
# 33805              0                          0                        0
# 40805              0                          0                        0
# 40811              0                          0                        0
#
#        province_aklan  province_albay  province_antipolo_city  \
# 0                   0               0                       0
# 948                 0               0                       0
# 1429                0               0                       0
# 1687                0               0                       0
# 1709                0               0                       0
# ...               ...             ...                     ...
# 18930               0               0                       0
# 26745               0               0                       0
# 33805               0               0                       0
# 40805               0               0                       0
# 40811               0               0                       0
#
#        province_antique  province_apayao  province_aurora  \
# 0                     0                0                0
# 948                   0                0                0
# 1429                  0                0                0
# 1687                  0                0                0
# 1709                  0                0                0
# ...                 ...              ...              ...
# 18930                 0                0                0
# 26745                 0                0                0
# 33805                 0                0                0
# 40805                 0                0                0
# 40811                 0                0                0
#
#        province_bacolod_city  ...  province_surigao_del_sur  \
# 0                          0  ...                         0
# 948                        0  ...                         0
# 1429                       0  ...                         0
# 1687                       0  ...                         0
# 1709                       0  ...                         0
# ...                      ...  ...                       ...
# 18930                      0  ...                         0
# 26745                      0  ...                         0
# 33805                      0  ...                         0
# 40805                      0  ...                         0
# 40811                      0  ...                         0
#
#        province_taguig-pateros  province_tarlac  province_tawi-tawi  \
# 0                            0                0                   0
# 948                          0                0                   0
# 1429                         0                0                   0
# 1687                         0                0                   0
# 1709                         0                0                   0
# ...                        ...              ...                 ...
# 18930                        0                0                   0
# 26745                        0                0                   0
# 33805                        0                0                   0
# 40805                        0                0                   0
# 40811                        0                0                   0
#
#        province_valenzuela_city  province_zambales  province_zamboanga_city  \
# 0                             0                  0                        0
# 948                           0                  0                        0
# 1429                          0                  0                        0
# 1687                          0                  0                        0
# 1709                          0                  0                        0
# ...                         ...                ...                      ...
# 18930                         0                  0                        0
# 26745                         0                  0                        0
# 33805                         0                  0                        0
# 40805                         0                  0                        0
# 40811                         0                  0                        0
#
#        province_zamboanga_del_norte  province_zamboanga_del_sur  \
# 0                                 0                           0
# 948                               0                           0
# 1429                              0                           0
# 1687                              0                           0
# 1709                              0                           0
# ...                             ...                         ...
# 18930                             0                           0
# 26745                             0                           0
# 33805                             0                           0
# 40805                             0                           0
# 40811                             0                           0
#
#        province_zamboanga_sibugay
# 0                               0
# 948                             0
# 1429                            0
# 1687                            0
# 1709                            0
# ...                           ...
# 18930                           0
# 26745                           0
# 33805                           0
# 40805                           0
# 40811                           0
#
# [40812 rows x 110 columns]

# %%
bill_to_author_df = bill_to_author_df.join(cols, how='inner')
bill_to_author_df
# Out:
#             ID  author_id                    rep_name          party  \
# 0      HB00001        284            Ungab, Isidro T.            HNP
# 948    HB00497        284            Ungab, Isidro T.            HNP
# 1429   HB00861        284            Ungab, Isidro T.            HNP
# 1687   HB01061        284            Ungab, Isidro T.            HNP
# 1709   HB01079        284            Ungab, Isidro T.            HNP
# ...        ...        ...                         ...            ...
# 18930  HB08231         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 26745  HB09411         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 33805  HB10153         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 40805  HB10831         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 40811  HB10833         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
#
#           region    province  is_partylist  party_1-pacman  party_a teacher  \
# 0      REGION XI  Davao City         False               0                0
# 948    REGION XI  Davao City         False               0                0
# 1429   REGION XI  Davao City         False               0                0
# 1687   REGION XI  Davao City         False               0                0
# 1709   REGION XI  Davao City         False               0                0
# ...          ...         ...           ...             ...              ...
# 18930        NaN         NaN          True               0                0
# 26745        NaN         NaN          True               0                0
# 33805        NaN         NaN          True               0                0
# 40805        NaN         NaN          True               0                0
# 40811        NaN         NaN          True               0                0
#
#        party_aambis-owa  ...  province_surigao_del_sur  \
# 0                     0  ...                         0
# 948                   0  ...                         0
# 1429                  0  ...                         0
# 1687                  0  ...                         0
# 1709                  0  ...                         0
# ...                 ...  ...                       ...
# 18930                 0  ...                         0
# 26745                 0  ...                         0
# 33805                 0  ...                         0
# 40805                 0  ...                         0
# 40811                 0  ...                         0
#
#        province_taguig-pateros  province_tarlac  province_tawi-tawi  \
# 0                            0                0                   0
# 948                          0                0                   0
# 1429                         0                0                   0
# 1687                         0                0                   0
# 1709                         0                0                   0
# ...                        ...              ...                 ...
# 18930                        0                0                   0
# 26745                        0                0                   0
# 33805                        0                0                   0
# 40805                        0                0                   0
# 40811                        0                0                   0
#
#        province_valenzuela_city  province_zambales  province_zamboanga_city  \
# 0                             0                  0                        0
# 948                           0                  0                        0
# 1429                          0                  0                        0
# 1687                          0                  0                        0
# 1709                          0                  0                        0
# ...                         ...                ...                      ...
# 18930                         0                  0                        0
# 26745                         0                  0                        0
# 33805                         0                  0                        0
# 40805                         0                  0                        0
# 40811                         0                  0                        0
#
#        province_zamboanga_del_norte  province_zamboanga_del_sur  \
# 0                                 0                           0
# 948                               0                           0
# 1429                              0                           0
# 1687                              0                           0
# 1709                              0                           0
# ...                             ...                         ...
# 18930                             0                           0
# 26745                             0                           0
# 33805                             0                           0
# 40805                             0                           0
# 40811                             0                           0
#
#        province_zamboanga_sibugay
# 0                               0
# 948                             0
# 1429                            0
# 1687                            0
# 1709                            0
# ...                           ...
# 18930                           0
# 26745                           0
# 33805                           0
# 40805                           0
# 40811                           0
#
# [40812 rows x 191 columns]

# %%
bill_to_author_df['region'].str.replace(' ', '_').str.lower().value_counts()
# Out:
# national_capital_region             5120
# region_iii                          3187
# region_v                            2926
# region_iv-a                         2803
# region_x                            2488
# region_i                            2188
# region_vii                          2158
# region_vi                           1874
# region_ii                           1859
# region_ix                           1307
# region_viii                         1196
# region_xi                           1159
# region_xiii                         1036
# cordillera_administrative_region     961
# region_xii                           946
# region_iv-b                          846
# barmm                                318
# Name: region, dtype: int64

# %%
print(bill_to_author_df.region.unique(), len(bill_to_author_df.region.unique()))
cols = pd.get_dummies(bill_to_author_df['region'].str.replace(' ', '_').str.lower())
cols = cols.rename({'cordillera_administrative_region': 'region_car', 'national_capital_region': 'region_ncr'})
cols
# Out:
# ['REGION XI' 'NATIONAL CAPITAL REGION' 'REGION IV-B' 'REGION VII'
#  'REGION V' 'REGION VI' 'REGION II' nan 'REGION III' 'REGION I'
#  'CORDILLERA ADMINISTRATIVE REGION' 'REGION XIII' 'REGION IV-A'
#  'REGION IX' 'REGION X' 'REGION VIII' 'REGION XII' 'BARMM'] 18
#        barmm  cordillera_administrative_region  national_capital_region  \
# 0          0                                 0                        0
# 948        0                                 0                        0
# 1429       0                                 0                        0
# 1687       0                                 0                        0
# 1709       0                                 0                        0
# ...      ...                               ...                      ...
# 18930      0                                 0                        0
# 26745      0                                 0                        0
# 33805      0                                 0                        0
# 40805      0                                 0                        0
# 40811      0                                 0                        0
#
#        region_i  region_ii  region_iii  region_iv-a  region_iv-b  region_ix  \
# 0             0          0           0            0            0          0
# 948           0          0           0            0            0          0
# 1429          0          0           0            0            0          0
# 1687          0          0           0            0            0          0
# 1709          0          0           0            0            0          0
# ...         ...        ...         ...          ...          ...        ...
# 18930         0          0           0            0            0          0
# 26745         0          0           0            0            0          0
# 33805         0          0           0            0            0          0
# 40805         0          0           0            0            0          0
# 40811         0          0           0            0            0          0
#
#        region_v  region_vi  region_vii  region_viii  region_x  region_xi  \
# 0             0          0           0            0         0          1
# 948           0          0           0            0         0          1
# 1429          0          0           0            0         0          1
# 1687          0          0           0            0         0          1
# 1709          0          0           0            0         0          1
# ...         ...        ...         ...          ...       ...        ...
# 18930         0          0           0            0         0          0
# 26745         0          0           0            0         0          0
# 33805         0          0           0            0         0          0
# 40805         0          0           0            0         0          0
# 40811         0          0           0            0         0          0
#
#        region_xii  region_xiii
# 0               0            0
# 948             0            0
# 1429            0            0
# 1687            0            0
# 1709            0            0
# ...           ...          ...
# 18930           0            0
# 26745           0            0
# 33805           0            0
# 40805           0            0
# 40811           0            0
#
# [40812 rows x 17 columns]

# %%
bill_to_author_df = bill_to_author_df.join(cols, how='inner')
bill_to_author_df
# Out:
#             ID  author_id                    rep_name          party  \
# 0      HB00001        284            Ungab, Isidro T.            HNP
# 948    HB00497        284            Ungab, Isidro T.            HNP
# 1429   HB00861        284            Ungab, Isidro T.            HNP
# 1687   HB01061        284            Ungab, Isidro T.            HNP
# 1709   HB01079        284            Ungab, Isidro T.            HNP
# ...        ...        ...                         ...            ...
# 18930  HB08231         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 26745  HB09411         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 33805  HB10153         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 40805  HB10831         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
# 40811  HB10833         67  Cardema, Ducielle Marie S.  DUTERTE YOUTH
#
#           region    province  is_partylist  party_1-pacman  party_a teacher  \
# 0      REGION XI  Davao City         False               0                0
# 948    REGION XI  Davao City         False               0                0
# 1429   REGION XI  Davao City         False               0                0
# 1687   REGION XI  Davao City         False               0                0
# 1709   REGION XI  Davao City         False               0                0
# ...          ...         ...           ...             ...              ...
# 18930        NaN         NaN          True               0                0
# 26745        NaN         NaN          True               0                0
# 33805        NaN         NaN          True               0                0
# 40805        NaN         NaN          True               0                0
# 40811        NaN         NaN          True               0                0
#
#        party_aambis-owa  ...  region_iv-b  region_ix  region_v  region_vi  \
# 0                     0  ...            0          0         0          0
# 948                   0  ...            0          0         0          0
# 1429                  0  ...            0          0         0          0
# 1687                  0  ...            0          0         0          0
# 1709                  0  ...            0          0         0          0
# ...                 ...  ...          ...        ...       ...        ...
# 18930                 0  ...            0          0         0          0
# 26745                 0  ...            0          0         0          0
# 33805                 0  ...            0          0         0          0
# 40805                 0  ...            0          0         0          0
# 40811                 0  ...            0          0         0          0
#
#        region_vii  region_viii  region_x  region_xi  region_xii  region_xiii
# 0               0            0         0          1           0            0
# 948             0            0         0          1           0            0
# 1429            0            0         0          1           0            0
# 1687            0            0         0          1           0            0
# 1709            0            0         0          1           0            0
# ...           ...          ...       ...        ...         ...          ...
# 18930           0            0         0          0           0            0
# 26745           0            0         0          0           0            0
# 33805           0            0         0          0           0            0
# 40805           0            0         0          0           0            0
# 40811           0            0         0          0           0            0
#
# [40812 rows x 208 columns]

# %% [markdown]
# Remove hot-encoded categories and authors field.

# %%
bill_to_author_df = bill_to_author_df.drop(['party', 'region', 'province', 'rep_name', 'author_id'], axis=1)

# %%
bill_to_author_df_consol = bill_to_author_df.groupby('ID').sum()
bill_to_author_df_consol
# Out:
#          is_partylist  party_1-pacman  party_a teacher  party_aambis-owa  \
# ID
# HB00001             0               0                0                 0
# HB00002             0               0                0                 0
# HB00003             0               0                0                 0
# HB00004             0               0                0                 0
# HB00005             0               0                0                 0
# ...               ...             ...              ...               ...
# HB10829             0               0                0                 0
# HB10830             0               0                0                 0
# HB10831             1               0                0                 0
# HB10832             0               0                0                 0
# HB10833             1               0                0                 0
#
#          party_abang lingkod  party_abono  party_act-cis  party_act-teachers  \
# ID
# HB00001                    0            0              0                   0
# HB00002                    0            0              0                   0
# HB00003                    0            0              0                   0
# HB00004                    0            0              0                   0
# HB00005                    0            0              0                   0
# ...                      ...          ...            ...                 ...
# HB10829                    0            0              0                   0
# HB10830                    0            0              0                   0
# HB10831                    0            0              0                   0
# HB10832                    0            0              0                   0
# HB10833                    0            0              0                   0
#
#          party_agap  party_ako bicol  ...  region_iv-b  region_ix  region_v  \
# ID                                    ...
# HB00001           0                0  ...            1          0         0
# HB00002           0                0  ...            0          0         0
# HB00003           0                0  ...            0          0         0
# HB00004           0                0  ...            0          0         0
# HB00005           0                0  ...            0          0         0
# ...             ...              ...  ...          ...        ...       ...
# HB10829           0                0  ...            0          0         0
# HB10830           0                0  ...            0          0         0
# HB10831           0                0  ...            0          0         0
# HB10832           0                0  ...            0          0         1
# HB10833           0                0  ...            0          0         0
#
#          region_vi  region_vii  region_viii  region_x  region_xi  region_xii  \
# ID
# HB00001          0           0            0         0          1           0
# HB00002          0           0            0         0          1           0
# HB00003          0           0            0         0          0           0
# HB00004          0           0            0         0          1           0
# HB00005          0           0            0         0          0           0
# ...            ...         ...          ...       ...        ...         ...
# HB10829          0           0            0         1          0           0
# HB10830          0           0            0         1          0           0
# HB10831          0           0            0         0          0           0
# HB10832          0           0            0         0          0           0
# HB10833          0           0            0         0          0           0
#
#          region_xiii
# ID
# HB00001            0
# HB00002            0
# HB00003            0
# HB00004            0
# HB00005            0
# ...              ...
# HB10829            0
# HB10830            0
# HB10831            0
# HB10832            0
# HB10833            0
#
# [10821 rows x 202 columns]

# %%
bills_df
# Out:
#             ID Significance  Date Filed  \
# 0      HB00001     National  2019-07-01
# 1      HB00002     National  2019-07-01
# 2      HB00003     National  2019-07-01
# 3      HB00004     National  2019-07-01
# 4      HB00005     National  2019-07-01
# ...        ...          ...         ...
# 10817  HB10829          NaN  2022-03-23
# 10818  HB10830          NaN  2022-03-23
# 10819  HB10831          NaN  2022-03-29
# 10820  HB10832          NaN  2022-03-31
# 10821  HB10833          NaN  2022-04-11
#
#                                               Full Title  \
# 0      AN ACT INSTITUTIONALIZING A NATIONAL VALUES, E...
# 1      AN ACT CREATING THE DEPARTMENT OF OVERSEAS FIL...
# 2      AN ACT PROVIDING FOR A NATIONAL PROGRAM TO SUP...
# 3      AN ACT CREATING THE EMERGENCY RESPONSE DEPARTM...
# 4      AN ACT INSTITUTIONALIZING MICROFINANCE PROGRAM...
# ...                                                  ...
# 10817  AN ACT CREATING THE "COUNCIL FOR THE BUILT ENV...
# 10818  AN ACT STRENGTHENING THE ARCHITECTURE PROFESSI...
# 10819  AN ACT POSTPONING THE DECEMBER 2022 BARANGAY A...
# 10820  AN ACT MANDATING ALL EXECUTIVE DEPARTMENTS, BU...
# 10821  AN ACT RENAMING THE NINOY AQUINO INTERNATIONAL...
#
#                                       Principal Author/s   Date Read  \
# 0      UNGAB, ISIDRO T.;CAYETANO, ALAN PETER "COMPAÑE...  2019-07-23
# 1      DUTERTE, PAOLO Z.;CAYETANO, MARIA LAARNI;CAYET...  2019-07-23
# 2                    CAYETANO, ALAN PETER "COMPAÑERO" S.  2019-07-23
# 3      DUTERTE, PAOLO Z.;CAYETANO, ALAN PETER "COMPAÑ...  2019-07-23
# 4                    CAYETANO, ALAN PETER "COMPAÑERO" S.  2019-07-23
# ...                                                  ...         ...
# 10817                                RODRIGUEZ, RUFUS B.         NaN
# 10818                                RODRIGUEZ, RUFUS B.         NaN
# 10819                                  CARDEMA, DUCIELLE         NaN
# 10820  FERNANDEZ, DAN S.;CAYETANO, ALAN PETER "COMPAÑ...         NaN
# 10821                                  CARDEMA, DUCIELLE         NaN
#
#                                      Primary Referral  \
# 0                         BASIC EDUCATION AND CULTURE
# 1                           GOVERNMENT REORGANIZATION
# 2                                 WELFARE OF CHILDREN
# 3                           GOVERNMENT REORGANIZATION
# 4      MICRO, SMALL AND MEDIUM ENTERPRISE DEVELOPMENT
# ...                                               ...
# 10817                                             NaN
# 10818                                             NaN
# 10819                                             NaN
# 10820                                             NaN
# 10821                                             NaN
#
#                                              Bill Status  \
# 0                                 Substituted by HB05829
# 1                                 Substituted by HB05832
# 2      Transmitted to the Committee on Appropriations...
# 3                                 Substituted by HB05989
# 4      Pending with the Committee on MICRO, SMALL AND...
# ...                                                  ...
# 10817      Pending First Reading (Filed last 2022-03-23)
# 10818      Pending First Reading (Filed last 2022-03-23)
# 10819      Pending First Reading (Filed last 2022-03-29)
# 10820      Pending First Reading (Filed last 2022-03-31)
# 10821      Pending First Reading (Filed last 2022-04-11)
#
#                                       Mother Bill Status  \
# 0             Republic Act RA11476 enacted on 2020-06-25
# 1             Republic Act RA11641 enacted on 2021-12-30
# 2                                                    NaN
# 3      Approved by the House on 2020-09-22, transmitt...
# 4                                                    NaN
# ...                                                  ...
# 10817                                                NaN
# 10818                                                NaN
# 10819                                                NaN
# 10820                                                NaN
# 10821                                                NaN
#
#       Date Approved on Second Reading Date Approved on Third Reading  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 10817                             NaN                            NaN
# 10818                             NaN                            NaN
# 10819                             NaN                            NaN
# 10820                             NaN                            NaN
# 10821                             NaN                            NaN
#
#       Senate Bill Counterpart Date Acted Upon By the President  \
# 0                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 3                         NaN                              NaN
# 4                         NaN                              NaN
# ...                       ...                              ...
# 10817                     NaN                              NaN
# 10818                     NaN                              NaN
# 10819                     NaN                              NaN
# 10820                     NaN                              NaN
# 10821                     NaN                              NaN
#
#       Republic Act No.  Author Count             indiv_cong  identified_tot
# 0                  NaN             3         [284, 72, 180]               3
# 1                  NaN             3          [104, 73, 72]               3
# 2                  NaN             1                   [72]               1
# 3                  NaN             2              [104, 72]               2
# 4                  NaN             1                   [72]               1
# ...                ...           ...                    ...             ...
# 10817              NaN             1                  [231]               1
# 10818              NaN             1                  [231]               1
# 10819              NaN             1                   [67]               1
# 10820              NaN             5  [121, 72, 3, 73, 294]               5
# 10821              NaN             1                   [67]               1
#
# [10821 rows x 17 columns]

# %%
reps_df.iloc[84]
# Out:
# rep_name                   Cuaresma, Luisa Lloren
# rep_region                          Nueva Vizcaya
# rep_subdistrict                     Lone District
# partylist                                     NaN
# link                                   cuaresma-l
# name               CUARESMA, LUISA LLOREN QUIRINO
# party                                         NUP
# votes                                     114,338
# conf_date                             14-May-2019
# district                            Lone District
# region                                  REGION II
# subdistrict                         Nueva Vizcaya
# Name: 84, dtype: object

# %% [markdown]
# Encode each author's participation as an adjacency list.

# %%
def adj_matrix(li, size):
    adj = [0 for _ in range(size)]
    for el in li:
        try:
            adj[el] = 1
        except:
            print(el)
    return adj
rep_count = len(rep_names.keys())
# skip individual congress members encoding for now
# bills_df[['cong_'+str(x) for x in range(rep_count)]] = bills_df['indiv_cong'].map(lambda x: adj_matrix(x, rep_count)).apply(pd.Series)
bills_df
# Out:
#             ID Significance  Date Filed  \
# 0      HB00001     National  2019-07-01
# 1      HB00002     National  2019-07-01
# 2      HB00003     National  2019-07-01
# 3      HB00004     National  2019-07-01
# 4      HB00005     National  2019-07-01
# ...        ...          ...         ...
# 10817  HB10829          NaN  2022-03-23
# 10818  HB10830          NaN  2022-03-23
# 10819  HB10831          NaN  2022-03-29
# 10820  HB10832          NaN  2022-03-31
# 10821  HB10833          NaN  2022-04-11
#
#                                               Full Title  \
# 0      AN ACT INSTITUTIONALIZING A NATIONAL VALUES, E...
# 1      AN ACT CREATING THE DEPARTMENT OF OVERSEAS FIL...
# 2      AN ACT PROVIDING FOR A NATIONAL PROGRAM TO SUP...
# 3      AN ACT CREATING THE EMERGENCY RESPONSE DEPARTM...
# 4      AN ACT INSTITUTIONALIZING MICROFINANCE PROGRAM...
# ...                                                  ...
# 10817  AN ACT CREATING THE "COUNCIL FOR THE BUILT ENV...
# 10818  AN ACT STRENGTHENING THE ARCHITECTURE PROFESSI...
# 10819  AN ACT POSTPONING THE DECEMBER 2022 BARANGAY A...
# 10820  AN ACT MANDATING ALL EXECUTIVE DEPARTMENTS, BU...
# 10821  AN ACT RENAMING THE NINOY AQUINO INTERNATIONAL...
#
#                                       Principal Author/s   Date Read  \
# 0      UNGAB, ISIDRO T.;CAYETANO, ALAN PETER "COMPAÑE...  2019-07-23
# 1      DUTERTE, PAOLO Z.;CAYETANO, MARIA LAARNI;CAYET...  2019-07-23
# 2                    CAYETANO, ALAN PETER "COMPAÑERO" S.  2019-07-23
# 3      DUTERTE, PAOLO Z.;CAYETANO, ALAN PETER "COMPAÑ...  2019-07-23
# 4                    CAYETANO, ALAN PETER "COMPAÑERO" S.  2019-07-23
# ...                                                  ...         ...
# 10817                                RODRIGUEZ, RUFUS B.         NaN
# 10818                                RODRIGUEZ, RUFUS B.         NaN
# 10819                                  CARDEMA, DUCIELLE         NaN
# 10820  FERNANDEZ, DAN S.;CAYETANO, ALAN PETER "COMPAÑ...         NaN
# 10821                                  CARDEMA, DUCIELLE         NaN
#
#                                      Primary Referral  \
# 0                         BASIC EDUCATION AND CULTURE
# 1                           GOVERNMENT REORGANIZATION
# 2                                 WELFARE OF CHILDREN
# 3                           GOVERNMENT REORGANIZATION
# 4      MICRO, SMALL AND MEDIUM ENTERPRISE DEVELOPMENT
# ...                                               ...
# 10817                                             NaN
# 10818                                             NaN
# 10819                                             NaN
# 10820                                             NaN
# 10821                                             NaN
#
#                                              Bill Status  \
# 0                                 Substituted by HB05829
# 1                                 Substituted by HB05832
# 2      Transmitted to the Committee on Appropriations...
# 3                                 Substituted by HB05989
# 4      Pending with the Committee on MICRO, SMALL AND...
# ...                                                  ...
# 10817      Pending First Reading (Filed last 2022-03-23)
# 10818      Pending First Reading (Filed last 2022-03-23)
# 10819      Pending First Reading (Filed last 2022-03-29)
# 10820      Pending First Reading (Filed last 2022-03-31)
# 10821      Pending First Reading (Filed last 2022-04-11)
#
#                                       Mother Bill Status  \
# 0             Republic Act RA11476 enacted on 2020-06-25
# 1             Republic Act RA11641 enacted on 2021-12-30
# 2                                                    NaN
# 3      Approved by the House on 2020-09-22, transmitt...
# 4                                                    NaN
# ...                                                  ...
# 10817                                                NaN
# 10818                                                NaN
# 10819                                                NaN
# 10820                                                NaN
# 10821                                                NaN
#
#       Date Approved on Second Reading Date Approved on Third Reading  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 10817                             NaN                            NaN
# 10818                             NaN                            NaN
# 10819                             NaN                            NaN
# 10820                             NaN                            NaN
# 10821                             NaN                            NaN
#
#       Senate Bill Counterpart Date Acted Upon By the President  \
# 0                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 3                         NaN                              NaN
# 4                         NaN                              NaN
# ...                       ...                              ...
# 10817                     NaN                              NaN
# 10818                     NaN                              NaN
# 10819                     NaN                              NaN
# 10820                     NaN                              NaN
# 10821                     NaN                              NaN
#
#       Republic Act No.  Author Count             indiv_cong  identified_tot
# 0                  NaN             3         [284, 72, 180]               3
# 1                  NaN             3          [104, 73, 72]               3
# 2                  NaN             1                   [72]               1
# 3                  NaN             2              [104, 72]               2
# 4                  NaN             1                   [72]               1
# ...                ...           ...                    ...             ...
# 10817              NaN             1                  [231]               1
# 10818              NaN             1                  [231]               1
# 10819              NaN             1                   [67]               1
# 10820              NaN             5  [121, 72, 3, 73, 294]               5
# 10821              NaN             1                   [67]               1
#
# [10821 rows x 17 columns]

# %%
li = {'source': [], 'target': []}
for src, dest_list in zip(bills_df['ID'].to_list(), bills_df['indiv_cong'].to_list()):
    for dest in dest_list:
        li['source'].append(src)
        li['target'].append(num_to_rep[dest])
graph_viz = pd.DataFrame(li)
graph_viz.to_csv('congress_bill_association_viz.csv', encoding='utf-8', index=False)

# %% [markdown]
# Drop redundant columns after adjacency matrix encoding. Remove cross-validation field `identified_tot`.

# %%
bills_df = bills_df.drop(['Principal Author/s', 'indiv_cong'], axis=1)

# %%
bills_df = bills_df.drop('identified_tot', axis=1)

# %%
bills_df.columns[:14]
# Out:
# Index(['ID', 'Significance', 'Date Filed', 'Full Title', 'Date Read',
#        'Primary Referral', 'Bill Status', 'Mother Bill Status',
#        'Date Approved on Second Reading', 'Date Approved on Third Reading',
#        'Senate Bill Counterpart', 'Date Acted Upon By the President',
#        'Republic Act No.', 'Author Count'],
#       dtype='object')

# %%
df = bills_df.set_index('ID').join(bill_to_author_df_consol, on='ID')
df
# Out:
#         Significance  Date Filed  \
# ID
# HB00001     National  2019-07-01
# HB00002     National  2019-07-01
# HB00003     National  2019-07-01
# HB00004     National  2019-07-01
# HB00005     National  2019-07-01
# ...              ...         ...
# HB10829          NaN  2022-03-23
# HB10830          NaN  2022-03-23
# HB10831          NaN  2022-03-29
# HB10832          NaN  2022-03-31
# HB10833          NaN  2022-04-11
#
#                                                 Full Title   Date Read  \
# ID
# HB00001  AN ACT INSTITUTIONALIZING A NATIONAL VALUES, E...  2019-07-23
# HB00002  AN ACT CREATING THE DEPARTMENT OF OVERSEAS FIL...  2019-07-23
# HB00003  AN ACT PROVIDING FOR A NATIONAL PROGRAM TO SUP...  2019-07-23
# HB00004  AN ACT CREATING THE EMERGENCY RESPONSE DEPARTM...  2019-07-23
# HB00005  AN ACT INSTITUTIONALIZING MICROFINANCE PROGRAM...  2019-07-23
# ...                                                    ...         ...
# HB10829  AN ACT CREATING THE "COUNCIL FOR THE BUILT ENV...         NaN
# HB10830  AN ACT STRENGTHENING THE ARCHITECTURE PROFESSI...         NaN
# HB10831  AN ACT POSTPONING THE DECEMBER 2022 BARANGAY A...         NaN
# HB10832  AN ACT MANDATING ALL EXECUTIVE DEPARTMENTS, BU...         NaN
# HB10833  AN ACT RENAMING THE NINOY AQUINO INTERNATIONAL...         NaN
#
#                                        Primary Referral  \
# ID
# HB00001                     BASIC EDUCATION AND CULTURE
# HB00002                       GOVERNMENT REORGANIZATION
# HB00003                             WELFARE OF CHILDREN
# HB00004                       GOVERNMENT REORGANIZATION
# HB00005  MICRO, SMALL AND MEDIUM ENTERPRISE DEVELOPMENT
# ...                                                 ...
# HB10829                                             NaN
# HB10830                                             NaN
# HB10831                                             NaN
# HB10832                                             NaN
# HB10833                                             NaN
#
#                                                Bill Status  \
# ID
# HB00001                             Substituted by HB05829
# HB00002                             Substituted by HB05832
# HB00003  Transmitted to the Committee on Appropriations...
# HB00004                             Substituted by HB05989
# HB00005  Pending with the Committee on MICRO, SMALL AND...
# ...                                                    ...
# HB10829      Pending First Reading (Filed last 2022-03-23)
# HB10830      Pending First Reading (Filed last 2022-03-23)
# HB10831      Pending First Reading (Filed last 2022-03-29)
# HB10832      Pending First Reading (Filed last 2022-03-31)
# HB10833      Pending First Reading (Filed last 2022-04-11)
#
#                                         Mother Bill Status  \
# ID
# HB00001         Republic Act RA11476 enacted on 2020-06-25
# HB00002         Republic Act RA11641 enacted on 2021-12-30
# HB00003                                                NaN
# HB00004  Approved by the House on 2020-09-22, transmitt...
# HB00005                                                NaN
# ...                                                    ...
# HB10829                                                NaN
# HB10830                                                NaN
# HB10831                                                NaN
# HB10832                                                NaN
# HB10833                                                NaN
#
#         Date Approved on Second Reading Date Approved on Third Reading  \
# ID
# HB00001                             NaN                            NaN
# HB00002                             NaN                            NaN
# HB00003                             NaN                            NaN
# HB00004                             NaN                            NaN
# HB00005                             NaN                            NaN
# ...                                 ...                            ...
# HB10829                             NaN                            NaN
# HB10830                             NaN                            NaN
# HB10831                             NaN                            NaN
# HB10832                             NaN                            NaN
# HB10833                             NaN                            NaN
#
#         Senate Bill Counterpart  ... region_iv-b region_ix  region_v  \
# ID                               ...
# HB00001                     NaN  ...           1         0         0
# HB00002                     NaN  ...           0         0         0
# HB00003                     NaN  ...           0         0         0
# HB00004                     NaN  ...           0         0         0
# HB00005                     NaN  ...           0         0         0
# ...                         ...  ...         ...       ...       ...
# HB10829                     NaN  ...           0         0         0
# HB10830                     NaN  ...           0         0         0
# HB10831                     NaN  ...           0         0         0
# HB10832                     NaN  ...           0         0         1
# HB10833                     NaN  ...           0         0         0
#
#          region_vi  region_vii  region_viii  region_x  region_xi  region_xii  \
# ID
# HB00001          0           0            0         0          1           0
# HB00002          0           0            0         0          1           0
# HB00003          0           0            0         0          0           0
# HB00004          0           0            0         0          1           0
# HB00005          0           0            0         0          0           0
# ...            ...         ...          ...       ...        ...         ...
# HB10829          0           0            0         1          0           0
# HB10830          0           0            0         1          0           0
# HB10831          0           0            0         0          0           0
# HB10832          0           0            0         0          0           0
# HB10833          0           0            0         0          0           0
#
#          region_xiii
# ID
# HB00001            0
# HB00002            0
# HB00003            0
# HB00004            0
# HB00005            0
# ...              ...
# HB10829            0
# HB10830            0
# HB10831            0
# HB10832            0
# HB10833            0
#
# [10821 rows x 215 columns]

# %%
df.to_csv('18th_hor_bills_dataset.csv', encoding='utf-8')

# %%
[col for col in df.columns if any(df[col].isna())]
# Out:
# ['Significance',
#  'Full Title',
#  'Date Read',
#  'Primary Referral',
#  'Bill Status',
#  'Mother Bill Status',
#  'Date Approved on Second Reading',
#  'Date Approved on Third Reading',
#  'Senate Bill Counterpart',
#  'Date Acted Upon By the President',
#  'Republic Act No.']
