# %% [markdown]
# # Bill Status
# The Bill Status column of the csv '18th_hor_bills_dataset_2.csv' contains where the bill is in its cycle. This python notebook attempts to classify the bills into either 'Approved' or 'Not Approved' based on the given data.
# ## Part 1: Uploading the Dataframe
# Upload the CSV file as a pandas Data Frame and print some entries to verify that the file was uploaded and read correctly.

# %%
import pandas as pd

#df = pd.read_csv('18th_hor_bills_dataset.csv')
df = pd.read_csv('18th_hor_bills_dataset_2.csv')

# %%
df_bill_status = df['Bill Status'].copy(deep = True)

print(len(df_bill_status))

df_bill_status1 = []
for i in df_bill_status:
    if isinstance(i, str):
        df_bill_status1.append(i)
    else:
        df_bill_status1.append("")
df_bill_status = df_bill_status1
print(len(df_bill_status))
# Out:
# 10821
# 10821

# %% [markdown]
# ## Part 2: Narrowing down Statuses
# From here, we check the statuses for recurring phrases to classify the bill status more easily before classifying them between 'Pass" and "Not Pass". The cell below looks for the most freqeuntly used phrases in the list df_status_bills

# %%
from nltk import ngrams
from collections import Counter

bill_status_split = [x for y in df['Bill Status'] for x in str(y).split()]
c = Counter([' '.join(x) for y in [2,3] for x in ngrams(bill_status_split, y)])

df_new = pd.DataFrame({'phrases': list(c.keys()), 'frequency': list(c.values())})
df_new = df_new.sort_values(by=['frequency'], ascending = False)
print(df_new)
# Out:
#                        phrases  frequency
# 8                 Committee on       6472
# 7                the Committee       6417
# 5661          the Committee on       6417
# 5670          Pending with the       6320
# 5671        with the Committee       6320
# ...                        ...        ...
# 7686    HB06727 Substituted by          1
# 7687    Substituted by HB08190          1
# 7688        by HB08190 Pending          1
# 7689      HB08190 Pending with          1
# 17003  (Filed last 2022-04-11)          1
#
# [17004 rows x 2 columns]

# %% [markdown]
# Given the phrases above, we now filter for phrases we need. We avoid phrases that have specifics ie date:

# %%
def filter_out(frequency, phrases):
    if frequency > 70:
        if 'since' not in phrases.lower():
            if re.search("\d{4}-\d{2}-\d{2}",phrases):
                return False
            else:
                if phrases.isupper():
                    return False
                else:
                    return True
        else:
            return False

# %%
import re
from tqdm.notebook import tqdm

filtered_list_frequency = []
filtered_list_phrases = []


for i in tqdm(range(len(df_new))):
    if filter_out(df_new.iloc[i]['frequency'], df_new.iloc[i]['phrases']):
        filtered_list_frequency.append(df_new.iloc[i]['frequency'])
        filtered_list_phrases.append(df_new.iloc[i]['phrases'])


print(len(filtered_list_frequency))

df2 = pd.DataFrame({'phrases': filtered_list_phrases, 'frequency': filtered_list_frequency})
for i in range(len(df2)):
    print(df2.iloc[i]['phrases'])
# Out:
#   0%|          | 0/17004 [00:00<?, ?it/s]
# 128
# Committee on
# the Committee
# the Committee on
# Pending with the
# with the Committee
# with the
# Pending with
# Substituted by
# by the
# the Senate
# Senate on
# the Senate on
# to the
# Committee on BASIC
# on BASIC
# on BASIC EDUCATION
# by the Senate
# by the House
# the House on
# House on
# the House
# Approved by
# to the Senate
# transmitted to the
# Approved by the
# transmitted to
# and received
# received by the
# and received by
# received by
# Committee on PUBLIC
# on PUBLIC
# Committee on HEALTH
# on HEALTH
# on LOCAL
# Committee on LOCAL
# on LOCAL GOVERNMENT
# on PUBLIC WORKS
# Committee on TRANSPORTATION
# on TRANSPORTATION
# on JUSTICE
# Committee on JUSTICE
# on GOVERNMENT
# Committee on GOVERNMENT
# Committee on LABOR
# on LABOR AND
# on LABOR
# on CIVIL
# enacted on
# Committee on CIVIL
# Republic Act
# on CIVIL SERVICE
# Consolidated into
# on AGRICULTURE
# Committee on AGRICULTURE
# on AGRICULTURE AND
# on HIGHER
# on HIGHER AND
# Committee on HIGHER
# on PUBLIC ORDER
# on GOVERNMENT ENTERPRISES
# on GOVERNMENT REORGANIZATION
# Transmitted to the
# Transmitted to
# on REVISION OF
# Committee on REVISION
# on REVISION
# Referred to
# on TRADE AND
# Committee on TRADE
# on TRADE
# Committee on NATURAL
# on NATURAL RESOURCES
# on NATURAL
# Consolidated into HB05712
# into HB05712
# on WAYS
# on INFORMATION
# Committee on INFORMATION
# on INFORMATION AND
# on WAYS AND
# Committee on WAYS
# Pending First Reading
# First Reading (Filed
# (Filed last
# Reading (Filed
# Reading (Filed last
# Pending First
# First Reading
# Committee on SENIOR
# on SENIOR CITIZENS
# on SENIOR
# on WELFARE
# Committee on WELFARE
# on WELFARE OF
# the President
# President on
# the President on
# to the President
# on APPROPRIATIONS
# Committee on APPROPRIATIONS
# Committee on BANKS
# on BANKS AND
# on BANKS
# Committee on DEFEAT
# on DEFEAT
# on DEFEAT COVID-19
# on AQUACULTURE
# on SUFFRAGE AND
# on SUFFRAGE
# on AQUACULTURE AND
# Committee on AQUACULTURE
# Committee on SUFFRAGE
# Passed by the
# Senate without amendments
# without amendments on
# amendments on
# without amendments
# Senate without
# the Senate without
# Passed by
# on HOUSING AND
# Committee on HOUSING
# Referred to Stakeholders
# to Stakeholders on
# Stakeholders on
# to Stakeholders
# on HOUSING

# %% [markdown]
# Being able to filter down the entries to 128 phrases, we can now look at phrases that can cluster the status to either Approved or Not Approved.
# Note that here, we manually select phrases that make sense:
# Will be marked as approved:
# - Approved by
# - Substituted by
# - No value (bill that was used to substitute an already existing bill)
#
# Will be marked as not approved:
# - Pending with
# - Transmitted to the
# - Consolidated into
# - Referred to
# - Pending First Reading
#
#
# Checking how many bills do not match with any of the phrases above:

# %%
approved_phrases = ["Approved by","Substituted by"]
not_approved_phrases = ["Pending with","Transmitted to the","Consolidated into","Referred to","Pending First Reading"]
collated_phrases = approved_phrases
collated_phrases.extend(not_approved_phrases)
print(collated_phrases)
classified = []
manual = []
checker = False

for i in tqdm(range(len(df_bill_status))):
    if isinstance(df_bill_status[i], str):
        for check_phrase in collated_phrases:
            if check_phrase.lower() in df_bill_status[i].lower():
                checker = True
                classified.append(df_bill_status[i])
                break
        if checker == False:
            manual.append(df_bill_status[i])
        else:
            checker = False
            
# missing 1 (NaN)

print(len(manual))
print(len(classified))
print(len(df_bill_status))
print(len(df_bill_status)-len(classified))
manual.sort()
for i in manual:
    print(i)
# Out:
# ['Approved by', 'Substituted by', 'Pending with', 'Transmitted to the', 'Consolidated into', 'Referred to', 'Pending First Reading']
#   0%|          | 0/10821 [00:00<?, ?it/s]
# 513
# 10308
# 10821
# 513
#
#  Action by the Plenary on September 21, 2021 reconsidered on September 30, 2021.
# Approved on Second Reading on 2022-02-02
# Approved on Second Reading on 2022-02-02
# Approved on Second Reading on 2022-02-02
# Approved on Second Reading on 2022-02-02
# Approved on Second Reading on 2022-02-02
# Approved on Second Reading on 2022-02-02
# Approved on Second Reading on 2022-02-02
# Approved on Second Reading on 2022-02-02
# Approved on Second Reading on 2022-02-02
# Approved on Second Reading on 2022-02-02
# Approved on Second Reading on 2022-02-02
# Approved on Second Reading on 2022-02-02
# Business for Thursday & Friday on 2021-02-23
# Business for Thursday & Friday on 2021-03-02
# Business for the day on 2019-11-11
# Business for the day on 2019-11-27
# Business for the day on 2020-02-19
# Business for the day on 2020-03-10
# Business for the day on 2020-03-10
# Business for the day on 2020-05-26
# Business for the day on 2020-05-26
# Business for the day on 2020-05-26
# Business for the day on 2020-05-28
# Business for the day on 2020-09-01
# Business for the day on 2020-10-14
# Business for the day on 2020-10-14
# Business for the day on 2020-10-14
# Business for the day on 2020-10-14
# Business for the day on 2021-08-02
# Business for the day on 2021-09-14
# Business for the day on 2021-09-20
# Business for the day on 2021-09-30
# Business for the day on 2021-11-17
# Business for the day on 2021-11-17
# Business for the day on 2021-12-07
# Business for the day on 2021-12-07
# Business for the day on 2021-12-07
# Business for the day on 2021-12-07
# Business for the day on 2022-01-24
# Business for the day on 2022-01-24
# Business for the day on 2022-01-25
# Business for the day on 2022-01-25
# Business for the day on 2022-01-25
# Business for the day on 2022-01-25
# Business for the day on 2022-02-02
# Business for the day on 2022-02-02
# Change of committee referral requested on 2019-09-30
# Change of committee referral requested on 2019-12-11
# Change of committee referral requested on 2020-01-21
# Change of committee referral requested on 2020-02-05
# Change of referral manifested on 2020-01-21
# Change of referral manifested on 2020-01-21
# Change of referral manifested on 2020-01-21
# Change of referral manifested on 2021-03-09
# Committee Report Signed by the Committee on Ways and Means on 2021-12-01
# Committee Report Signed by the Committee on Ways and Means on 2021-12-01
# Committee Report Signed by the Committee on Ways and Means on 2021-12-01
# Committee Report filed on 2020-08-04
# Consigned to the Archives on 2021-02-01
# Deliberated by the TWG on 2019-10-02
# Deliberated by the TWG on 2019-10-02
# Deliberated by the TWG on 2019-10-02
# Deliberated by the TWG on 2019-10-02
# Deliberated by the TWG on 2019-10-02
# Deliberated by the TWG on 2019-12-11
# Deliberated by the TWG on 2020-03-04
# Deliberated by the TWG on 2020-03-04
# Deliberated by the TWG on 2020-03-04
# Deliberated by the TWG on 2021-02-04
# Deliberated by the TWG on 2021-02-04
# Deliberated by the TWG on 2021-05-27
# Deliberated by the TWG on 2021-06-01
# Deliberated by the TWG on 2021-06-01
# Deliberated upon by the Mother Committee on 2019-09-23
# Deliberated upon by the Mother Committee on 2019-11-05
# Deliberated upon by the Mother Committee on 2019-11-05
# Deliberated upon by the Mother Committee on 2019-11-05
# Deliberated upon by the Mother Committee on 2019-11-05
# Deliberated upon by the Mother Committee on 2019-11-05
# Deliberated upon by the Mother Committee on 2019-11-25
# Deliberated upon by the Mother Committee on 2019-11-27
# Deliberated upon by the Mother Committee on 2019-11-27
# Deliberated upon by the Mother Committee on 2019-12-02
# Deliberated upon by the Mother Committee on 2019-12-09
# Deliberated upon by the Mother Committee on 2020-02-18
# Deliberated upon by the Mother Committee on 2020-03-03
# Deliberated upon by the Mother Committee on 2020-03-09
# Deliberated upon by the Mother Committee on 2020-07-15
# Deliberated upon by the Mother Committee on 2020-07-15
# Deliberated upon by the Mother Committee on 2020-07-15
# Deliberated upon by the Mother Committee on 2020-08-07
# Deliberated upon by the Mother Committee on 2020-08-26
# Deliberated upon by the Mother Committee on 2020-08-26
# Deliberated upon by the Mother Committee on 2020-12-08
# Deliberated upon by the Mother Committee on 2020-12-08
# Deliberated upon by the Mother Committee on 2021-01-20
# Deliberated upon by the Mother Committee on 2021-01-26
# Deliberated upon by the Mother Committee on 2021-01-26
# Deliberated upon by the Mother Committee on 2021-01-27
# Deliberated upon by the Mother Committee on 2021-01-27
# Deliberated upon by the Mother Committee on 2021-03-03
# Deliberated upon by the Mother Committee on 2021-03-03
# Deliberated upon by the Mother Committee on 2021-03-03
# Deliberated upon by the Mother Committee on 2021-03-23
# Deliberated upon by the Mother Committee on 2021-03-23
# Deliberated upon by the Mother Committee on 2021-03-23
# Deliberated upon by the Mother Committee on 2021-03-23
# Deliberated upon by the Mother Committee on 2021-03-23
# Deliberated upon by the Mother Committee on 2021-03-23
# Deliberated upon by the Mother Committee on 2021-05-19
# Deliberated upon by the Mother Committee on 2021-05-19
# Deliberated upon by the Mother Committee on 2021-05-19
# Deliberated upon by the Mother Committee on 2021-05-19
# Deliberated upon by the Mother Committee on 2021-05-19
# Deliberated upon by the Mother Committee on 2021-05-19
# Deliberated upon by the Mother Committee on 2021-05-19
# Deliberated upon by the Mother Committee on 2021-05-25
# Deliberated upon by the Mother Committee on 2021-05-25
# Deliberated upon by the Mother Committee on 2021-05-25
# Deliberated upon by the Mother Committee on 2021-05-25
# Deliberated upon by the Mother Committee on 2021-05-25
# Deliberated upon by the Mother Committee on 2021-05-25
# Deliberated upon by the Mother Committee on 2021-05-25
# Deliberated upon by the Mother Committee on 2021-05-25
# Deliberated upon by the Mother Committee on 2021-05-25
# Deliberated upon by the Mother Committee on 2021-05-25
# Deliberated upon by the Mother Committee on 2021-08-24
# Deliberated upon by the Mother Committee on 2021-11-29
# Draft Committee Report and attachments reviewed by the ED/Date received/Date routed out on 2021-02-10
# Draft Committee Report and attachments reviewed by the ED/Date received/Date routed out on 2021-02-10
# Draft Committee Report and attachments reviewed by the ED/Date received/Date routed out on 2021-02-10
# Draft Committee Report reviewed by the ED/Date received/Date routed out on 2020-12-14
# Draft Committee Report reviewed by the ED/Date received/Date routed out on 2020-12-14
# Draft Committee Report reviewed by the ED/Date received/Date routed out on 2021-02-10
# Draft Committee Report reviewed by the ED/Date received/Date routed out on 2021-02-10
# House adopted Senate Bill as amendment to House Bill on 2022-02-02
# House adopted Senate Bill as amendment to House Bill on 2022-02-02
# House adopted Senate Bill as amendment to House Bill on 2022-02-02
# House agreed on 2022-01-17 to the request for a conference made by the Senate on 2021-12-16
# House agreed on 2022-02-02 to the request for a conference made by the Senate on 2022-01-31
# House agreed on 2022-02-02 to the request for a conference made by the Senate on 2022-01-31
# House agreed to the amendments of the Senate on 2021-12-14
# House agreed to the amendments of the Senate on 2022-01-24
# House agreed to the amendments of the Senate on 2022-01-24
# House agreed to the amendments of the Senate on 2022-01-31
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House agreed to the amendments of the Senate on 2022-02-02
# House ratified the CC report on 2022-01-24, Senate on 2022-01-24
# House ratified the CC report on 2022-01-26, Senate on 2022-01-25
# House ratified the CC report on 2022-02-02, Senate on 2022-02-02
# House ratified the CC report on 2022-02-02, Senate on 2022-02-02
# House ratified the CC report on 2022-02-02, Senate on 2022-02-02
# House ratified the CC report on 2022-02-02, Senate on 2022-02-02
# House requested for a conference committee on 2022-02-02
# Measure recommitted on 2020-12-14
# Measure recommitted on 2021-08-31
# Measure recommitted on 2021-09-01
# Measure recommitted on 2021-11-23
# Measure recommitted on 2022-01-25
# Measure reconsidered on 2020-02-24
# Measure reconsidered on 2020-11-23
# Measure reconsidered on 2020-12-14
# Measure reconsidered on 2021-11-22
# Measure reconsidered on 2022-02-02
# Passed by the Senate without amendments on 2022-01-17
# Passed by the Senate without amendments on 2022-01-17
# Passed by the Senate without amendments on 2022-01-17
# Passed by the Senate without amendments on 2022-01-17
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Passed by the Senate without amendments on 2022-01-31
# Period of amendment closed on 2021-03-16
# Period of sponsorship/debate closed on 2021-11-22
# Printed copies distributed to members on 2019-10-22
# Printed copies distributed to members on 2019-11-28
# Printed copies distributed to members on 2019-12-12
# Printed copies distributed to members on 2020-05-14
# Printed copies distributed to members on 2020-12-03
# Printed copies distributed to members on 2021-06-24
# Printed copies distributed to members on 2021-09-09
# Printed copies distributed to members on 2021-11-18
# REPUBLIC ACT RA11503 (Lapsed into law on 2020-12-20)
# REPUBLIC ACT RA11504 (Lapsed into law on 2020-12-20)
# REPUBLIC ACT RA11505 (Lapsed into law on 2020-12-20)
# REPUBLIC ACT RA11506 (Lapsed into law on 2020-12-20)
# REPUBLIC ACT RA11507 (Lapsed into law on 2020-12-21)
# REPUBLIC ACT RA11508 (Lapsed into law on 2020-12-21)
# REPUBLIC ACT RA11512 (Lapsed into law on 2020-12-26)
# REPUBLIC ACT RA11513 (Lapsed into law on 2020-12-26)
# REPUBLIC ACT RA11514 (Lapsed into law on 2020-12-26)
# REPUBLIC ACT RA11515 (Lapsed into law on 2020-12-26)
# REPUBLIC ACT RA11516 (Lapsed into law on 2020-12-26)
# Reported out 2022-02-02 (#01452);Submitted by LOCAL GOVERNMENT, APPROPRIATIONS, WAYS AND MEANS
# Reported out 2022-02-02 (#01453)
# Reported out 2022-02-07 (#01455);Submitted by HEALTH, APPROPRIATIONS
# Reported out 2022-02-10 (#01456);Submitted by OVERSEAS WORKERS AFFAIRS
# Reported out 2022-02-23 (#01457);Submitted by METRO MANILA DEVELOPMENT, TRANSPORTATION
# Reported out 2022-03-01 (#01459);Submitted by FOREIGN AFFAIRS
# Reported out 2022-03-16 (#01460);Submitted by ENERGY
# Reported out 2022-03-22 (#01461);Submitted by NATURAL RESOURCES
# Republic Act RA11462 enacted on 2019-12-03
# Republic Act RA11463 enacted on 2019-12-03
# Republic Act RA11464 enacted on 2019-12-20
# Republic Act RA11465 enacted on 2020-01-06
# Republic Act RA11466 enacted on 2020-01-08
# Republic Act RA11467 enacted on 2020-01-22
# Republic Act RA11468 enacted on 2020-01-23
# Republic Act RA11469 enacted on 2020-03-24
# Republic Act RA11470 enacted on 2020-06-09
# Republic Act RA11471 enacted on 2020-06-19
# Republic Act RA11472 enacted on 2020-06-19
# Republic Act RA11473 enacted on 2020-06-19
# Republic Act RA11474 enacted on 2020-06-19
# Republic Act RA11475 enacted on 2020-06-19
# Republic Act RA11476 enacted on 2020-06-25
# Republic Act RA11477 enacted on 2020-06-25
# Republic Act RA11478 enacted on 2020-07-01
# Republic Act RA11479 enacted on 2020-07-03
# Republic Act RA11480 enacted on 2020-07-17
# Republic Act RA11481 enacted on 2020-07-30
# Republic Act RA11482 enacted on 2020-07-30
# Republic Act RA11483 enacted on 2020-08-14
# Republic Act RA11484 enacted on 2020-08-14
# Republic Act RA11485 enacted on 2020-08-14
# Republic Act RA11486 enacted on 2020-08-14
# Republic Act RA11487 enacted on 2020-08-14
# Republic Act RA11488 enacted on 2020-08-14
# Republic Act RA11489 enacted on 2020-08-14
# Republic Act RA11490 enacted on 2020-08-14
# Republic Act RA11491 enacted on 2020-08-14
# Republic Act RA11492 enacted on 2020-08-14
# Republic Act RA11493 enacted on 2020-08-14
# Republic Act RA11494 enacted on 2020-09-11
# Republic Act RA11495 enacted on 2020-11-13
# Republic Act RA11496 enacted on 2020-11-13
# Republic Act RA11497 enacted on 2020-11-13
# Republic Act RA11498 enacted on 2020-11-13
# Republic Act RA11499 enacted on 2020-11-13
# Republic Act RA11500 enacted on 2020-11-13
# Republic Act RA11501 enacted on 2020-11-13
# Republic Act RA11502 enacted on 2020-12-16
# Republic Act RA11509 enacted on 2020-12-23
# Republic Act RA11510 enacted on 2020-12-23
# Republic Act RA11511 enacted on 2020-12-23
# Republic Act RA11517 enacted on 2020-12-23
# Republic Act RA11518 enacted on 2020-12-28
# Republic Act RA11519 enacted on 2020-12-29
# Republic Act RA11520 enacted on 2020-12-29
# Republic Act RA11521 enacted on 2021-01-29
# Republic Act RA11522 enacted on 2021-02-05
# Republic Act RA11523 enacted on 2021-02-16
# Republic Act RA11524 enacted on 2021-02-26
# Republic Act RA11525 enacted on 2021-02-26
# Republic Act RA11526 enacted on 2021-03-12
# Republic Act RA11527 enacted on 2021-03-12
# Republic Act RA11528 enacted on 2021-03-12
# Republic Act RA11529 enacted on 2021-03-12
# Republic Act RA11530 enacted on 2021-03-12
# Republic Act RA11531 enacted on 2021-03-12
# Republic Act RA11532 enacted on 2021-03-24
# Republic Act RA11533 enacted on 2021-03-25
# Republic Act RA11534 enacted on 2021-03-26
# Republic Act RA11535 enacted on 2021-04-09
# Republic Act RA11536 enacted on 2021-05-14
# Republic Act RA11537 enacted on 2021-05-18
# Republic Act RA11538 enacted on 2021-05-18
# Republic Act RA11539 enacted on 2021-05-18
# Republic Act RA11540 enacted on 2021-05-18
# Republic Act RA11541 enacted on 2021-05-18
# Republic Act RA11542 enacted on 2021-05-18
# Republic Act RA11543 enacted on 2021-05-18
# Republic Act RA11544 enacted on 2021-05-26
# Republic Act RA11545 enacted on 2021-05-23
# Republic Act RA11546 enacted on 2021-05-26
# Republic Act RA11547 enacted on 2021-05-27
# Republic Act RA11548 enacted on 2021-05-26
# Republic Act RA11549 enacted on 2021-05-26
# Republic Act RA11550 enacted on 2021-05-27
# Republic Act RA11551 enacted on 2021-05-27
# Republic Act RA11552 enacted on 2021-05-27
# Republic Act RA11553 enacted on 2021-06-24
# Republic Act RA11554 enacted on 2021-06-24
# Republic Act RA11555 enacted on 2021-06-24
# Republic Act RA11556 enacted on 2021-06-24
# Republic Act RA11557 enacted on 2021-06-24
# Republic Act RA11558 enacted on 2021-06-24
# Republic Act RA11559 enacted on 2021-06-24
# Republic Act RA11560 enacted on 2021-06-24
# Republic Act RA11561 enacted on 2021-06-24
# Republic Act RA11562 enacted on 2021-06-24
# Republic Act RA11563 enacted on 2021-06-24
# Republic Act RA11564 enacted on 2021-06-24
# Republic Act RA11565 enacted on 2021-06-24
# Republic Act RA11566 enacted on 2021-06-24
# Republic Act RA11567 enacted on 2021-06-24
# Republic Act RA11568 enacted on 2021-06-24
# Republic Act RA11569 enacted on 2021-06-30
# Republic Act RA11570 enacted on 2021-07-02
# Republic Act RA11571 enacted on 2021-07-06
# Republic Act RA11572 enacted on 2021-07-30
# Republic Act RA11573 enacted on 2021-07-16
# Republic Act RA11574 enacted on 2021-07-23
# Republic Act RA11575 enacted on 2021-07-23
# Republic Act RA11576 enacted on 2021-07-30
# Republic Act RA11577 enacted on 2021-07-30
# Republic Act RA11578 enacted on 2021-07-30
# Republic Act RA11579 enacted on 2021-07-30
# Republic Act RA11580 enacted on 2021-07-23
# Republic Act RA11581 enacted on 2021-07-23
# Republic Act RA11582 enacted on 2021-07-30
# Republic Act RA11583 enacted on 2021-07-30
# Republic Act RA11584 enacted on 2021-07-30
# Republic Act RA11585 enacted on 2021-07-30
# Republic Act RA11586 enacted on 2021-07-30
# Republic Act RA11587 enacted on 2021-07-30
# Republic Act RA11588 enacted on 2021-08-12
# Republic Act RA11589 enacted on 2021-09-10
# Republic Act RA11590 enacted on 2021-09-22
# Republic Act RA11591 enacted on 2021-09-30
# Republic Act RA11592 enacted on 2021-10-14
# Republic Act RA11593 enacted on 2021-10-28
# Republic Act RA11594 enacted on 2021-10-29
# Republic Act RA11595 enacted on 2021-12-10
# Republic Act RA11596 enacted on 2021-12-10
# Republic Act RA11597 enacted on 2021-12-10
# Republic Act RA11598 enacted on 2021-12-10
# Republic Act RA11599 enacted on 2021-12-10
# Republic Act RA11600 enacted on 2021-12-10
# Republic Act RA11601 enacted on 2021-12-10
# Republic Act RA11602 enacted on 2021-12-10
# Republic Act RA11603 enacted on 2021-12-10
# Republic Act RA11604 enacted on 2021-12-10
# Republic Act RA11605 enacted on 2021-12-10
# Republic Act RA11606 enacted on 2021-12-10
# Republic Act RA11607 enacted on 2021-12-10
# Republic Act RA11608 enacted on 2021-12-10
# Republic Act RA11609 enacted on 2021-12-10
# Republic Act RA11610 enacted on 2021-12-10
# Republic Act RA11611 enacted on 2021-12-10
# Republic Act RA11612 enacted on 2021-12-10
# Republic Act RA11613 enacted on 2021-12-10
# Republic Act RA11614 enacted on 2021-12-10
# Republic Act RA11615 enacted on 2021-12-10
# Republic Act RA11616 enacted on 2021-12-10
# Republic Act RA11617 enacted on 2021-12-10
# Republic Act RA11618 enacted on 2021-12-10
# Republic Act RA11619 enacted on 2021-12-10
# Republic Act RA11620 enacted on 2021-12-10
# Republic Act RA11621 enacted on 2021-12-10
# Republic Act RA11622 enacted on 2021-12-10
# Republic Act RA11623 enacted on 2021-12-10
# Republic Act RA11624 enacted on 2021-12-10
# Republic Act RA11625 enacted on 2021-12-10
# Republic Act RA11626 enacted on 2021-12-10
# Republic Act RA11627 enacted on 2021-12-10
# Republic Act RA11628 enacted on 2021-12-10
# Republic Act RA11629 enacted on 2021-12-10
# Republic Act RA11630 enacted on 2021-12-10
# Republic Act RA11631 enacted on 2021-12-10
# Republic Act RA11632 enacted on 2021-12-10
# Republic Act RA11633 enacted on 2021-12-10
# Republic Act RA11634 enacted on 2021-12-10
# Republic Act RA11635 enacted on 2021-12-10
# Republic Act RA11636 enacted on 2021-12-10
# Republic Act RA11637 enacted on 2021-12-10
# Republic Act RA11638 enacted on 2021-12-10
# Republic Act RA11639 enacted on 2021-12-30
# Republic Act RA11640 enacted on 2021-12-30
# Republic Act RA11641 enacted on 2021-12-30
# Republic Act RA11642 enacted on 2022-01-06
# Republic Act RA11643 enacted on 2022-01-11
# Republic Act RA11644 enacted on 2022-01-14
# Republic Act RA11645 enacted on 2022-01-14
# Republic Act RA11646 enacted on 2022-01-21
# Republic Act RA11647 enacted on 2022-03-02
# Republic Act RA11648 enacted on 2022-03-04
# Republic Act RA11649 enacted on 2022-03-08
# Republic Act RA11650 enacted on 2022-03-11
# Republic Act RA11651 enacted on 2022-03-11
# Republic Act RA11652 enacted on 2022-03-11
# Republic Act RA11653 enacted on 2022-03-11
# Republic Act RA11654 enacted on 2022-03-11
# Republic Act RA11655 enacted on 2022-03-11
# Republic Act RA11656 enacted on 2022-03-11
# Republic Act RA11657 enacted on 2022-03-11
# Republic Act RA11658 enacted on 2022-03-11
# Republic Act RA11659 enacted on 2022-03-21
# Republic Act RA11664 enacted on 2022-03-29
# Republic Act RA11665 enacted on 2022-03-29
# Republic Act RA11666 enacted on 2022-03-29
# Republic Act RA11667 enacted on 2022-03-29
# Republic Act RA11668 enacted on 2022-03-29
# Republic Act RA11669 enacted on 2022-03-29
# Republic Act RA11670 enacted on 2022-03-29
# Republic Act RA11671 enacted on 2022-04-01
# Republic Act RA11672 enacted on 2022-04-06
# Republic Act RA11673 enacted on 2022-04-08
# Republic Act RA11674 enacted on 2022-04-08
# Republic Act RA11675 enacted on 2022-04-08
# Republic Act RA11676 enacted on 2022-04-08
# Republic Act RA11677 enacted on 2022-04-08
# Republic Act RA11678 enacted on 2022-04-08
# Republic Act RA11679 enacted on 2022-04-08
# Republic Act RA11680 enacted on 2022-04-08
# Republic Act RA11681 enacted on 2022-04-08
# Senate agreed on 2021-09-07 to the request for a conference made by the House on 2021-09-06
# Senate agreed on 2022-01-31 to the request for a conference made by the House on 2022-01-31
# Senate agreed on 2022-02-02 to the request for a conference made by the House on 2022-02-02
# Senate reconsidered approval on Third Reading on 2022-02-02
# Senate reconsidered approval on Third Reading on 2022-02-02
# Tabled by the Committee on 2020-02-18
# Tabled by the Committee on 2020-08-07
# Transmmitted to the Committee on Ways and Means on 2020-09-15
# Unfinished Business (Period of Interpellation)
# Unfinished Business (Period of Sponsorship)
# Unfinished Business (Period of Sponsorship)
# Unfinished Business (Period of Sponsorship)
# Unfinished Business (Period of Sponsorship)
# Unfinished Business (Period of Sponsorship)
# Unfinished Business (Period of Sponsorship)

# %% [markdown]
# More classifiers can be added in light of the list above:
#
# Approved:
# - Approved on Second Reading
# - Committee Report Signed
# - Consigned to the Archives
# - House adopted Senate Bill
# - House agreed [...]
# - House ratified
# - Measure recommitted
# - Passed by the Senate without amendments
# - REPUBLIC ACT/ Lapsed into law n [...]
# - Republic Act/ enacted on [...]
#
#
# Not Approved:
# - Business for [...]
# - Change of  [...]
# - Period of [...]
# - Printed copies distributed to members [...]
# - Senate reconsidered approval on Third Reading
# - Tabled by the Committee
# - Transmitted to the COmmittee
# - Unfinished Business
#
# - Delibearted upon/ Deliberated by the TWG
# - Deliberated upon by the Mother Committee
# - Draft Committee Report and attachments reviewed
# - Draft Committee Report reviewed by the ED/Date received/Date
# - Measure reconsidered
# - Senate agreed on [...]
#
# Consolidating this into the phrases:

# %%
approved_phrases = ["Approved by","Substituted by","Approved on Second Reading","Committee Report Signed","Consigned to the Archives",
                    "House adopted Senate Bill","House agreed","House ratified","Measure recommitted","Passed by the Senate without amendments",
                    "REPUBLIC ACT","enacted on"]
not_approved_phrases = ["Pending with","Transmitted to the","Consolidated into","Referred to","Pending First Reading",
                       "Business for","Change of","Period of","Printed copies distributed to members","Senate reconsidered approval on Third Reading",
                        "Tabled by the Committee","Transmitted to the Committee", "Unfinished Business","Deliberated upon","Deliberated by the TWG",
                       "Deliberated upon by the Mother Committee","Draft Committee Report and attachments reviewed","Draft Committee Report reviewed by the ED/Date received/Date",
                       "Measure reconsidered","Senate agreed on"]

# %% [markdown]
# We now add more columns in the CSV for the Verdict. This will be hot encoded later on.

# %%
import pandas as pd
df = pd.read_csv('18th_hor_bills_dataset_2.csv')
df["Verdict"] = ""
df.to_csv("18th_hor_bills_dataset_2.csv", index=False)

# %%
for i in tqdm(range(len(df))):
    #print(df['Bill Status'][i]) 
    #print(i)
    if isinstance(df['Bill Status'][i], str):
        df["Verdict"][i] = "Not Approved"
        for ii in approved_phrases:
            if ii.lower() in df['Bill Status'][i].lower():
                #print("approved")
                df["Verdict"][i] = "Approved"
    else:
        df["Verdict"][i] = "Not Approved"
        
df.to_csv("18th_hor_bills_dataset_2.csv", index=False)
# Out:
#   0%|          | 0/10821 [00:00<?, ?it/s]
# C:\Users\Michael Morco\AppData\Local\Temp/ipykernel_8020/4268007167.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Verdict"][i] = "Not Approved"
# C:\Users\Michael Morco\AppData\Local\Temp/ipykernel_8020/4268007167.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Verdict"][i] = "Approved"
# C:\Users\Michael Morco\AppData\Local\Temp/ipykernel_8020/4268007167.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Verdict"][i] = "Not Approved"

# %% [markdown]
# Cell below randomly selects 15 of the bills from the CSV for manual checking.

# %%
import random
for i in range(10):
    n = random.randint(0,10822)
    print(df["Bill Status"][n])
    print(df["Verdict"][n])
    print("---")
# Out:
# Pending with the Committee on AGRICULTURE AND FOOD since 2019-07-24
# Not Approved
# ---
# Measure approved by the Committee on 2021-11-24
# Approved
# ---
# Pending with the Committee on BASIC EDUCATION AND CULTURE since 2020-03-09
# Not Approved
# ---
# Substituted by HB05659
# Approved
# ---
# Pending with the Committee on BASIC EDUCATION AND CULTURE since 2019-07-29
# Not Approved
# ---
# Substituted by HB05698
# Approved
# ---
# Substituted by HB06135
# Approved
# ---
# Approved by the House on 2022-01-17, transmitted to the Senate on 2022-01-24 and received by the Senate on 2022-01-24
# Approved
# ---
# Pending with the Committee on PERSONS WITH DISABILITIES since 2020-01-21
# Not Approved
# ---
# Consolidated into HB09411
# Not Approved
# ---

# %% [markdown]
# ## Significance and Primary Referral One Hot Encoding
#
# Here, we encode one-hot encoding for the columns Significance and Primary Referral. First, we need to look for the categories:

# %%
def get_categories(df,column):
    list_of_categories = []
    for i in tqdm(range(len(df))):
        if isinstance(df[column][i], str):
            if df[column][i] not in list_of_categories:
                list_of_categories.append(df[column][i])
    return list_of_categories

# %%
significance_list = []
primary_referrals = []
significance_list = get_categories(df, "Significance")
print(significance_list)
primary_referrals = get_categories(df, "Primary Referral")
print(primary_referrals)
# Out:
#   0%|          | 0/10821 [00:00<?, ?it/s]
# ['National', 'Local']
#   0%|          | 0/10821 [00:00<?, ?it/s]
# ['BASIC EDUCATION AND CULTURE', 'GOVERNMENT REORGANIZATION', 'WELFARE OF CHILDREN', 'MICRO, SMALL AND MEDIUM ENTERPRISE DEVELOPMENT', 'APPROPRIATIONS', 'HEALTH', 'ECONOMIC AFFAIRS', 'AGRICULTURE AND FOOD', 'GOVERNMENT ENTERPRISES AND PRIVATIZATION', 'PUBLIC INFORMATION', 'TRANSPORTATION', 'HUMAN RIGHTS', 'PUBLIC WORKS AND HIGHWAYS', 'LOCAL GOVERNMENT', 'LABOR AND EMPLOYMENT', 'NATIONAL DEFENSE AND SECURITY', 'PUBLIC ORDER AND SAFETY', 'ECOLOGY', 'NATURAL RESOURCES', 'INFORMATION AND COMMUNICATIONS TECHNOLOGY', 'TRADE AND INDUSTRY', 'HOUSING AND URBAN DEVELOPMENT', 'SUFFRAGE AND ELECTORAL REFORMS', 'CIVIL SERVICE AND PROFESSIONAL REGULATION', 'REFORESTATION', 'BASES CONVERSION', 'SENIOR CITIZENS', 'YOUTH AND SPORTS DEVELOPMENT', 'DANGEROUS DRUGS', 'WOMEN AND GENDER EQUALITY', 'HIGHER AND TECHNICAL EDUCATION', 'FOREIGN AFFAIRS', 'POPULATION AND FAMILY RELATIONS', "PEOPLE'S PARTICIPATION", 'JUSTICE', 'LAND USE', 'WAYS AND MEANS', 'ENERGY', 'SCIENCE AND TECHNOLOGY', 'TOURISM', 'REVISION OF LAWS', 'BANKS AND FINANCIAL INTERMEDIARIES', 'OVERSEAS WORKERS AFFAIRS', 'DISASTER RESILIENCE', 'POVERTY ALLEVIATION', 'FOOD SECURITY', 'AGRARIAN REFORM', 'COOPERATIVES DEVELOPMENT', 'LEGISLATIVE FRANCHISES', 'RURAL DEVELOPMENT', 'CLIMATE CHANGE', 'INDIGENOUS CULTURAL COMMUNITIES AND INDIGENOUS PEOPLES', 'VETERANS AFFAIRS AND WELFARE', 'AD HOC COMMITTEE ON THE MILITARY AND UNIFORMED PERSONNEL(MUP) PENSION SYSTEM', 'METRO MANILA DEVELOPMENT', 'CONSTITUTIONAL AMENDMENTS', 'AQUACULTURE AND FISHERIES RESOURCES', 'PERSONS WITH DISABILITIES', 'MUSLIM AFFAIRS', 'GAMES AND AMUSEMENTS', 'CREATIVE INDUSTRY AND PERFORMING ARTS', 'RULES', 'PUBLIC ACCOUNTS', 'SOCIAL SERVICES', 'PEACE, RECONCILIATION AND UNITY', 'VISAYAS DEVELOPMENT', 'FLAGSHIP PROGRAMS AND PROJECTS', 'SUSTAINABLE DEVELOPMENT GOALS', 'DEFEAT COVID-19 AD-HOC COMMITTEE', 'THE WHOLE HOUSE', 'MINDANAO AFFAIRS', 'WEST PHILIPPINE SEA']

# %% [markdown]
# The function hot_encode below creates a column with the category name coming from above. ALl values are initially set to 0. Tje function "make nice" eliminates spaces and makes text all lowercase for column headers.

# %%
def hot_encode(df, list_of_categories):
    for category in list_of_categories:
        category_name = category.lower()
        df[category_name] = 0

# %%
def make_nice(list_of_categories):
    new_list = []
    for item in list_of_categories:
        item_name = item.lower().replace(" ","_")
        new_list.append(item_name)
    return new_list

# %% [markdown]
# A list for approved/not approved is also created for the verdict one-hot encoding.

# %%
primary_referral_list = make_nice(primary_referrals)
hot_encode(df, significance_list)
hot_encode(df, primary_referral_list)
hot_encode(df, ["approved","not_approved"])
df.to_csv("18th_hor_bills_dataset_2.csv", index=False)

# %% [markdown]
# The cell below updates National/Local and Approved/Not approved columns (1 indicating yes).

# %%
for i in tqdm(range(len(df))):
#for i in tqdm(range(15)):
    if df["Significance"][i] == "National":
        df['national'][i] = 1
    else:
        df['local'][i] = 1
        
    if df['Verdict'][i] == "Approved":
        #print('approved')
        df['approved'][i] = 1
    else:
        df['not_approved'][i] = 1
        
df.to_csv("18th_hor_bills_dataset_2.csv", index=False)
# Out:
#   0%|          | 0/10821 [00:00<?, ?it/s]
# C:\Users\Michael Morco\AppData\Local\Temp/ipykernel_8020/1957541098.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['national'][i] = 1
# C:\Users\Michael Morco\AppData\Local\Temp/ipykernel_8020/1957541098.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['approved'][i] = 1
# C:\Users\Michael Morco\AppData\Local\Temp/ipykernel_8020/1957541098.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['not_approved'][i] = 1
# C:\Users\Michael Morco\AppData\Local\Temp/ipykernel_8020/1957541098.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['local'][i] = 1

# %% [markdown]
# Similar to the cell above, the cell below updates the values (from 0 to 1 if yes) for columns under the 'Primary referral' list.

# %%
for i in tqdm(range(len(df))):
    if isinstance(df["Primary Referral"][i], str):
        pref = primary_referrals.index(df["Primary Referral"][i])
        df[primary_referral_list[pref]][i] = 1
df.to_csv("18th_hor_bills_dataset_2.csv", index=False)
# Out:
#   0%|          | 0/10821 [00:00<?, ?it/s]
# C:\Users\Michael Morco\AppData\Local\Temp/ipykernel_8020/2045370714.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[primary_referral_list[pref]][i] = 1

# %% [markdown]
# Changes can now be found in the CSV.
